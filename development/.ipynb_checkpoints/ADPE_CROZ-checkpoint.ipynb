# %% [markdown]
# # Finding the temporal autocorrelation order and evidence of slope
# This notebook fits an ARIMA model for ADPE at CROZIER

# %%
# Load libraries
library(forecast); library(ggplot2);library(dplyr); library(fmsb); library(stats); library(ggplot2); library(modelr); library(lmtest); library(pdp)

# %%
# Load the data
master<-read.csv("~/Workspace/Anthropocene/data/MASTER_SIE_MOD.csv")

# %%
head(master)
# Out:
#   year intP_RSP  mnChl_aw_RSP mnOW_RSP nmSST_aw_RSP intP_MCM  mnChl_aw_MCM
# 1 1998 0.6511596 1.161487     250157   -0.690398    0.7170871 1.2969463
# 2 1999 0.6556949 1.353060     218399   -0.901666    0.7196705 1.5053741
# 3 2000 0.5873935 1.098477     200943   -0.924639    0.3527637 0.6385173
# 4 2001 0.7697252 1.460241     250135   -0.645706    1.0612940 3.1205994
# 5 2002 0.2079730 0.311760     100918   -1.117230    0.1219010 0.1905980
# 6 2003 0.6588100 1.278130     190735   -1.047010    0.1797500 0.2424260
#   mnOW_MCM nmSST_aw_MCM mnAirTemp ⋯ ICEBERG ADPE_BIRD ADPE_CROZ ADPE_RO BIRD
# 1 4370.76  -0.758259    -5.650    ⋯ 0       38252     125441    34110   38252
# 2 4127.91  -0.926631    -5.900    ⋯ 0       47350     156441    36200   47350
# 3 2959.68  -1.109230    -4.450    ⋯ 0       41409      89489    23630   41409
# 4 4366.66  -0.911519    -6.175    ⋯ 1       26317      67114    13670   26317
# 5 1748.01  -1.109550    -6.050    ⋯ 1       40678     161079    22390   40678
# 6 2701.45  -1.177640    -4.625    ⋯ 1       22816     100843    19630   22816
#   EMPE WESE      WESE_1 av_SIE FIE
# 1 1108 0.6388527   NA   3.126  17.2
# 2  798 0.6505867   NA   3.269  31.0
# 3 1201 0.6219035 1.05   2.983  37.2
# 4    0 0.5084746 0.75   2.964  15.0
# 5  247 0.5345502 0.80   2.779  44.9
# 6  279 0.5084746 0.78   2.859  52.0

# %%
## We don't need this - delete?
cor(master[,2:19], use="pairwise.complete.obs")
# Out:
#                 intP_RSP    mnChl_aw_RSP mnOW_RSP    nmSST_aw_RSP intP_MCM
# intP_RSP         1.00000000  0.94454059   0.43946403  0.27914517   0.46626966
# mnChl_aw_RSP     0.94454059  1.00000000   0.30699532  0.10071579   0.40239192
# mnOW_RSP         0.43946403  0.30699532   1.00000000  0.73515178   0.36247779
# nmSST_aw_RSP     0.27914517  0.10071579   0.73515178  1.00000000   0.28656746
# intP_MCM         0.46626966  0.40239192   0.36247779  0.28656746   1.00000000
# mnChl_aw_MCM     0.47509991  0.41793630   0.34140018  0.31352540   0.96015360
# mnOW_MCM         0.20546020  0.23656242   0.27249496  0.02364183   0.65538634
# nmSST_aw_MCM     0.11394521  0.09016437   0.17605577  0.21796171   0.70334063
# mnAirTemp       -0.11334898 -0.20072185   0.29523669  0.04534470  -0.24827392
# mnWind          -0.32466601 -0.22680718   0.02686311 -0.10174371  -0.03686866
# mnSIE            0.31072775  0.31406067  -0.08468916 -0.08050543   0.38056155
# GyreSPD          0.34618575  0.27976270   0.53154088  0.46223973   0.04972926
# TOTALDays.10     0.01945864 -0.01672189   0.28695238  0.31511063  -0.44713347
# TOTALTonnes.100 -0.17689146 -0.10200719   0.20759040  0.15310548  -0.29967025
# Prop._134        0.17552870  0.16457189   0.12221040 -0.23512779  -0.38878302
# Fish            -0.02740464  0.01992529   0.21722373 -0.03261421  -0.39403845
# Fish_cum3        0.11541248  0.17142970   0.28598322 -0.03324664  -0.03937376
# Fish_cum_8_9_1   0.11739387  0.16991122   0.29323717 -0.03059136  -0.05295556
#                 mnChl_aw_MCM  mnOW_MCM    nmSST_aw_MCM mnAirTemp
# intP_RSP         0.4750999142  0.20546020  0.113945215 -0.113348985
# mnChl_aw_RSP     0.4179363019  0.23656242  0.090164369 -0.200721848
# mnOW_RSP         0.3414001773  0.27249496  0.176055767  0.295236691
# nmSST_aw_RSP     0.3135254006  0.02364183  0.217961714  0.045344700
# intP_MCM         0.9601535953  0.65538634  0.703340634 -0.248273920
# mnChl_aw_MCM     1.0000000000  0.56133437  0.566210746 -0.207887937
# mnOW_MCM         0.5613343671  1.00000000  0.733401537 -0.081912713
# nmSST_aw_MCM     0.5662107457  0.73340154  1.000000000 -0.292763566
# mnAirTemp       -0.2078879370 -0.08191271 -0.292763566  1.000000000
# mnWind           0.0006840325  0.42529357  0.078641091  0.020317756
# mnSIE            0.3103883890  0.24011766  0.437285175 -0.341448171
# GyreSPD          0.1218408492 -0.07045841 -0.239659074  0.463923320
# TOTALDays.10    -0.3395537751 -0.20128946 -0.321421086  0.156291971
# TOTALTonnes.100 -0.2524948297  0.13268317 -0.006536279  0.178507600
# Prop._134       -0.4315362231  0.02294064 -0.352427708  0.344588538
# Fish            -0.3600801233  0.14994056 -0.249369505  0.253265080
# Fish_cum3       -0.0983294044  0.36073469  0.127059045  0.003897865
# Fish_cum_8_9_1  -0.1120167019  0.35843576  0.108700987  0.015315366
#                 mnWind        mnSIE        GyreSPD     TOTALDays.10
# intP_RSP        -0.3246660054  0.310727749  0.34618575  0.01945864
# mnChl_aw_RSP    -0.2268071808  0.314060671  0.27976270 -0.01672189
# mnOW_RSP         0.0268631066 -0.084689160  0.53154088  0.28695238
# nmSST_aw_RSP    -0.1017437071 -0.080505432  0.46223973  0.31511063
# intP_MCM        -0.0368686575  0.380561552  0.04972926 -0.44713347
# mnChl_aw_MCM     0.0006840325  0.310388389  0.12184085 -0.33955378
# mnOW_MCM         0.4252935742  0.240117662 -0.07045841 -0.20128946
# nmSST_aw_MCM     0.0786410913  0.437285175 -0.23965907 -0.32142109
# mnAirTemp        0.0203177558 -0.341448171  0.46392332  0.15629197
# mnWind           1.0000000000 -0.281021435 -0.03382712  0.35443254
# mnSIE           -0.2810214350  1.000000000 -0.10267168 -0.19960684
# GyreSPD         -0.0338271205 -0.102671680  1.00000000  0.17815266
# TOTALDays.10     0.3544325421 -0.199606840  0.17815266  1.00000000
# TOTALTonnes.100  0.3995117560 -0.353856087  0.05977268  0.65237885
# Prop._134       -0.0277379005 -0.004746331  0.16233667  0.25893579
# Fish             0.2953161745 -0.270201538  0.11558764  0.64251185
# Fish_cum3        0.1113744138  0.248239449 -0.04047038  0.45253208
# Fish_cum_8_9_1   0.1177736752  0.228572403 -0.02951148  0.46380474
#                 TOTALTonnes.100 Prop._134    Fish        Fish_cum3
# intP_RSP        -0.176891460     0.175528697 -0.02740464  0.115412482
# mnChl_aw_RSP    -0.102007188     0.164571889  0.01992529  0.171429696
# mnOW_RSP         0.207590402     0.122210397  0.21722373  0.285983224
# nmSST_aw_RSP     0.153105479    -0.235127787 -0.03261421 -0.033246641
# intP_MCM        -0.299670253    -0.388783019 -0.39403845 -0.039373757
# mnChl_aw_MCM    -0.252494830    -0.431536223 -0.36008012 -0.098329404
# mnOW_MCM         0.132683170     0.022940643  0.14994056  0.360734695
# nmSST_aw_MCM    -0.006536279    -0.352427708 -0.24936951  0.127059045
# mnAirTemp        0.178507600     0.344588538  0.25326508  0.003897865
# mnWind           0.399511756    -0.027737901  0.29531617  0.111374414
# mnSIE           -0.353856087    -0.004746331 -0.27020154  0.248239449
# GyreSPD          0.059772683     0.162336666  0.11558764 -0.040470382
# TOTALDays.10     0.652378849     0.258935790  0.64251185  0.452532078
# TOTALTonnes.100  1.000000000     0.069651358  0.75695399  0.753133516
# Prop._134        0.069651358     1.000000000  0.65100319  0.445597137
# Fish             0.756953987     0.651003191  1.00000000  0.851577294
# Fish_cum3        0.753133516     0.445597137  0.85157729  1.000000000
# Fish_cum_8_9_1   0.751194178     0.469946129  0.86928086  0.999286225
#                 Fish_cum_8_9_1
# intP_RSP         0.11739387
# mnChl_aw_RSP     0.16991122
# mnOW_RSP         0.29323717
# nmSST_aw_RSP    -0.03059136
# intP_MCM        -0.05295556
# mnChl_aw_MCM    -0.11201670
# mnOW_MCM         0.35843576
# nmSST_aw_MCM     0.10870099
# mnAirTemp        0.01531537
# mnWind           0.11777368
# mnSIE            0.22857240
# GyreSPD         -0.02951148
# TOTALDays.10     0.46380474
# TOTALTonnes.100  0.75119418
# Prop._134        0.46994613
# Fish             0.86928086
# Fish_cum3        0.99928622
# Fish_cum_8_9_1   1.00000000

# %%
#calculating the annual percentage change for ADPE_CROZ
master_gr <- master %>% mutate(growth_croz=log(ADPE_CROZ/lag(ADPE_CROZ)))
master_gr$growth_croz<-ifelse(is.na(master_gr$growth_croz),0,master_gr$growth_croz)
master_gr[1,"growth_croz"]<--0.2011873


#taking out years before 2003#
master_gr <- subset(master_gr, !year %in% c(1998:2002))

# %%
#taking out iceberg years#
master_gr1 <- subset(master_gr, !year %in% c(2001:2005))

# %% [markdown]
# # Including LAGS

# %%
master_gr$mnOW_RSP6<- master_gr$mnOW_RSP/10^6

# %%
#lag 5 years SIE
master_gr <- master_gr %>% mutate(SIE_lag5 = lag(av_SIE,5))
master_gr[5,"SIE_lag5"]<-2.703
master_gr[4,"SIE_lag5"]<-3.123
master_gr[3,"SIE_lag5"]<-2.731
master_gr[2,"SIE_lag5"]<-2.767
master_gr[1,"SIE_lag5"]<-2.60

#lag 4 years SIE
master_gr <- master_gr %>% mutate(SIE_lag4 = lag(av_SIE,4))
master_gr[4,"SIE_lag4"]<-2.703
master_gr[3,"SIE_lag4"]<-3.123
master_gr[2,"SIE_lag4"]<-2.731
master_gr[1,"SIE_lag4"]<-2.767


#lag 4 years Gyre
master_gr <- master_gr %>% mutate(GyreSPD_lag4 = lag(GyreSPD,4))
master_gr[4,"GyreSPD_lag4"]<-6.2
master_gr[3,"GyreSPD_lag4"]<-6.3
master_gr[2,"GyreSPD_lag4"]<-5.7
master_gr[1,"GyreSPD_lag4"]<-5.8

#lag 5 years Gyre
master_gr <- master_gr %>% mutate(GyreSPD_lag5 = lag(GyreSPD,5))
master_gr[5,"GyreSPD_lag5"]<-6.2
master_gr[4,"GyreSPD_lag5"]<-6.3
master_gr[3,"GyreSPD_lag5"]<-5.7
master_gr[2,"GyreSPD_lag5"]<-5.8
master_gr[1,"GyreSPD_lag5"]<-5.0

#lag 5 years Air Temp
master_gr <- master_gr %>% mutate(mnAirTemp_lag5 = lag(mnAirTemp,5))
master_gr[5,"mnAirTemp_lag5"]<--5.6
master_gr[4,"mnAirTemp_lag5"]<--4.5
master_gr[3,"mnAirTemp_lag5"]<--5.2
master_gr[2,"mnAirTemp_lag5"]<--7.7
master_gr[1,"mnAirTemp_lag5"]<--4.2

#lag 4 years Air Temp
master_gr <- master_gr %>% mutate(mnAirTemp_lag4 = lag(mnAirTemp,4))
master_gr[5,"mnAirTemp_lag4"]<--5.6
master_gr[4,"mnAirTemp_lag4"]<--4.5
master_gr[3,"mnAirTemp_lag4"]<--5.2
master_gr[2,"mnAirTemp_lag4"]<--7.7

#lag 5 years SST
master_gr <- master_gr %>% mutate(nmSST_aw_RSP_lag5 = lag(nmSST_aw_RSP,5))
master_gr[5,"nmSST_aw_RSP_lag5"]<--1.11723
master_gr[4,"nmSST_aw_RSP_lag5"]<--0.645706
master_gr[3,"nmSST_aw_RSP_lag5"]<--0.924639
master_gr[2,"nmSST_aw_RSP_lag5"]<--0.901666
master_gr[1,"nmSST_aw_RSP_lag5"]<--0.690398

#lag 4 years SST
master_gr <- master_gr %>% mutate(nmSST_aw_RSP_lag4 = lag(nmSST_aw_RSP,4))
master_gr[4,"nmSST_aw_RSP_lag4"]<--1.11723
master_gr[3,"nmSST_aw_RSP_lag4"]<--0.645706
master_gr[2,"nmSST_aw_RSP_lag4"]<--0.924639
master_gr[1,"nmSST_aw_RSP_lag4"]<--0.901666

#lag 5 years Wind
master_gr <- master_gr %>% mutate(mnWind_lag5 = lag(mnWind,5))
master_gr[5,"mnWind_lag5"]<-8.8
master_gr[4,"mnWind_lag5"]<-8.6
master_gr[3,"mnWind_lag5"]<-7.8
master_gr[2,"mnWind_lag5"]<-7.8
master_gr[1,"mnWind_lag5"]<-7.8

#lag 4 years Wind
master_gr <- master_gr %>% mutate(mnWind_lag4 = lag(mnWind,4))
master_gr[4,"mnWind_lag4"]<-8.8
master_gr[3,"mnWind_lag4"]<-8.6
master_gr[2,"mnWind_lag4"]<-7.8
master_gr[1,"mnWind_lag4"]<-7.8

#mnOW_RSP6
master_gr$mnOW_RSP6<- master_gr$mnOW_RSP/10^6

#lag 5 years mnOW_RSP6
master_gr <- master_gr %>% mutate(mnOW_RSP6_lag5 = lag(mnOW_RSP6,5))
master_gr[5,"mnOW_RSP6_lag5"]<-100918/10^6
master_gr[4,"mnOW_RSP6_lag5"]<-250135/10^6
master_gr[3,"mnOW_RSP6_lag5"]<-200943/10^6
master_gr[2,"mnOW_RSP6_lag5"]<-218399/10^6
master_gr[1,"mnOW_RSP6_lag5"]<-250157/10^6

#lag 4 years mnOW_RSP6
master_gr <- master_gr %>% mutate(mnOW_RSP6_lag4 = lag(mnOW_RSP6,4))
master_gr[4,"mnOW_RSP6_lag4"]<-100918/10^6
master_gr[3,"mnOW_RSP6_lag4"]<-250135/10^6
master_gr[2,"mnOW_RSP6_lag4"]<-200943/10^6
master_gr[1,"mnOW_RSP6_lag4"]<-218399/10^6

# %%
master_gr;summary(master_gr$growth_croz); summary(master_gr$mnOW_RSP)
# Out:
#    year intP_RSP mnChl_aw_RSP mnOW_RSP nmSST_aw_RSP intP_MCM  mnChl_aw_MCM
# 1  2003 0.658810 1.278130     190735   -1.047010    0.1797500 0.2424260
# 2  2004 0.659537 1.201000     268734   -0.546599    0.0595893 0.0920093
# 3  2005 0.617897 1.116710     236044   -0.551816    0.2451990 0.5341190
# 4  2006 0.673591 1.344420     218199   -0.970962    0.3927390 0.5908280
# 5  2007 0.543325 1.170400     188097   -1.006890    0.3533950 0.6396110
# 6  2008 0.525248 0.962226     241795   -0.846050    0.2566900 0.5890600
# 7  2009 0.739713 1.811370     227884   -0.983647    0.4709990 1.1855100
# 8  2010 0.658263 1.361110     254659   -0.702852    0.6655190 1.6221900
# 9  2011 0.530627 0.988240     238928   -1.043260    0.3446910 0.5803630
# 10 2012 0.619356 1.160120     224013   -0.806416    0.5633720 1.5237500
# 11 2013 0.480733 0.760245     260754   -0.548099    0.5862910 1.1578700
# 12 2014 0.469865 1.010510     184900   -0.946211    0.2947150 0.6039610
# 13 2015 0.550999 1.069580     238508   -0.828653    0.6110260 1.3640600
# 14 2016 0.715440 1.582850     235490   -0.661670    0.4544810 0.9937190
# 15 2017 0.345075 0.608589     263830   -0.720451    0.2543610 0.4013860
# 16 2018 0.430345 0.787736     245847   -0.820266    0.4504050 1.0538200
# 17 2019       NA       NA         NA          NA           NA        NA
#    mnOW_MCM nmSST_aw_MCM mnAirTemp ⋯ GyreSPD_lag4_2 GyreSPD_lag5_2 Salinity_2
# 1  2701.45  -1.177640    -4.625    ⋯ 33.64          25.00          1213.547
# 2  1115.63  -1.394120    -5.000    ⋯ 32.49          33.64          1213.477
# 3  3630.16  -1.099050    -5.250    ⋯ 39.69          32.49          1210.692
# 4  4718.94  -0.954533    -6.000    ⋯ 38.44          39.69          1211.040
# 5  3903.53  -1.064650    -6.800    ⋯ 49.00          38.44                NA
# 6  1968.25  -1.173800    -5.025    ⋯ 51.84          49.00          1212.432
# 7  5003.04  -0.939651    -5.475    ⋯ 60.84          51.84                NA
# 8  4676.62  -0.910408    -4.800    ⋯ 29.16          60.84          1211.040
# 9  3446.75  -1.145310    -4.475    ⋯ 24.01          29.16                NA
# 10 3799.97  -1.007750    -4.325    ⋯ 54.76          24.01          1209.301
# 11 4809.29  -0.529366    -5.475    ⋯ 37.21          54.76          1209.648
# 12 3855.74  -0.991542    -5.425    ⋯ 60.84          37.21          1208.605
# 13 4850.60  -0.801907    -5.275    ⋯ 31.36          60.84                NA
# 14 2029.15  -1.027590    -6.175    ⋯ 40.96          31.36          1208.953
# 15 3262.14  -1.148770    -4.700    ⋯ 25.00          40.96          1212.432
# 16 4958.09  -1.057240    -4.700    ⋯ 44.89          25.00          1214.523
# 17      NA         NA        NA    ⋯ 54.76          44.89                NA
#    intP_RSP_2 Prop._134_2 TOTALTonnes.100_2 mnSIE_2   mnAirTemp_2
# 1  0.4340306  3025         201.0923          8.173881 21.39062
# 2  0.4349891  1225         426.2491          7.612081 25.00000
# 3  0.3817967  1444        1125.8508          8.020224 27.56250
# 4  0.4537248  2025         729.6968          7.496644 36.00000
# 5  0.2952021  1764         814.4232          9.771876 46.24000
# 6  0.2758855  1681         500.7257         10.029889 25.25063
# 7  0.5471753  1764         503.3786          9.431041 29.97562
# 8  0.4333102  1521         906.0702          8.880400 23.04000
# 9  0.2815650  1225         861.3873          7.595536 20.02562
# 10 0.3836019   676         972.1986          7.778521 18.70563
# 11 0.2311042   441        1080.3317          9.690769 29.97562
# 12 0.2207731   289         888.6003          9.174841 29.43062
# 13 0.3035999   324         717.1684          8.352100 27.82563
# 14 0.5118544   100         795.2400          7.338681 38.13062
# 15 0.1190768  1369         718.2400          5.841889 22.09000
# 16 0.1851968  1024         695.3769          7.022500 22.09000
# 17        NA    NA               NA                NA       NA
#    mnAirTemp_lag4_2 mnAirTemp_lag5_2
# 1        NA         17.64000
# 2  59.29000         59.29000
# 3  27.04000         27.04000
# 4  20.25000         20.25000
# 5  31.36000         31.36000
# 6  25.00000         21.39062
# 7  27.56250         25.00000
# 8  36.00000         27.56250
# 9  46.24000         36.00000
# 10 25.25063         46.24000
# 11 29.97562         25.25063
# 12 23.04000         29.97562
# 13 20.02562         23.04000
# 14 18.70563         20.02562
# 15 29.97562         18.70563
# 16 29.43062         29.97562
# 17 27.82563         29.43062
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -0.46833 -0.02230  0.02294  0.03899  0.06346  0.59314
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#  184900  222560  237276  232401  248050  268734       1

# %% [markdown]
# # Quadratic variables

# %%
master_gr$SIE_lag4_2<- master_gr$SIE_lag4^2
master_gr$SIE_lag5_2<- master_gr$SIE_lag5^2
master_gr$mnOW_RSP6<- master_gr$mnOW_RSP/10^6
master_gr$mnOW_RSP6_2<-master_gr$mnOW_RSP6^2
master_gr$mnOW_RSP6_lag4_2<-master_gr$mnOW_RSP6_lag4^2
master_gr$mnOW_RSP6_lag5_2<-master_gr$mnOW_RSP6_lag5^2
master_gr$mnChl_aw_RSP_2<-master_gr$mnChl_aw_RSP^2
master_gr$nmSST_aw_RSP_2<-master_gr$nmSST_aw_RSP^2
master_gr$nmSST_aw_RSP_lag4_2<-master_gr$nmSST_aw_RSP_lag4^2
master_gr$nmSST_aw_RSP_lag5_2<-master_gr$nmSST_aw_RSP_lag5^2
master_gr$mnWind_2<-master_gr$mnWind^2
master_gr$mnWind_lag4_2<-master_gr$mnWind_lag4^2
master_gr$mnWind_lag5_2<-master_gr$mnWind_lag5^2
master_gr$GyreSPD_2<-master_gr$GyreSPD^2
master_gr$GyreSPD_lag4_2<-master_gr$GyreSPD_lag4^2
master_gr$GyreSPD_lag5_2<-master_gr$GyreSPD_lag5^2
master_gr$Salinity_2<-master_gr$Salinity^2
master_gr$intP_RSP_2<-master_gr$intP_RSP^2
master_gr$Prop._134_2<-master_gr$Prop._134^2
master_gr$TOTALTonnes.100_2<-master_gr$TOTALTonnes.100^2
master_gr$mnSIE_2<- master_gr$mnSIE^2
master_gr$mnAirTemp_2<- master_gr$mnAirTemp^2
master_gr$mnAirTemp_lag4_2<- master_gr$mnAirTemp_lag4^2
master_gr$mnAirTemp_lag5_2<- master_gr$mnAirTemp_lag5^2

# %%
head(master_gr)
# Out:
#   year intP_RSP mnChl_aw_RSP mnOW_RSP nmSST_aw_RSP intP_MCM  mnChl_aw_MCM
# 1 2003 0.658810 1.278130     190735   -1.047010    0.1797500 0.2424260
# 2 2004 0.659537 1.201000     268734   -0.546599    0.0595893 0.0920093
# 3 2005 0.617897 1.116710     236044   -0.551816    0.2451990 0.5341190
# 4 2006 0.673591 1.344420     218199   -0.970962    0.3927390 0.5908280
# 5 2007 0.543325 1.170400     188097   -1.006890    0.3533950 0.6396110
# 6 2008 0.525248 0.962226     241795   -0.846050    0.2566900 0.5890600
#   mnOW_MCM nmSST_aw_MCM mnAirTemp ⋯ GyreSPD_lag4_2 GyreSPD_lag5_2 Salinity_2
# 1 2701.45  -1.177640    -4.625    ⋯ 33.64          25.00          1213.547
# 2 1115.63  -1.394120    -5.000    ⋯ 32.49          33.64          1213.477
# 3 3630.16  -1.099050    -5.250    ⋯ 39.69          32.49          1210.692
# 4 4718.94  -0.954533    -6.000    ⋯ 38.44          39.69          1211.040
# 5 3903.53  -1.064650    -6.800    ⋯ 49.00          38.44                NA
# 6 1968.25  -1.173800    -5.025    ⋯ 51.84          49.00          1212.432
#   intP_RSP_2 Prop._134_2 TOTALTonnes.100_2 mnSIE_2   mnAirTemp_2
# 1 0.4340306  3025         201.0923          8.173881 21.39062
# 2 0.4349891  1225         426.2491          7.612081 25.00000
# 3 0.3817967  1444        1125.8508          8.020224 27.56250
# 4 0.4537248  2025         729.6968          7.496644 36.00000
# 5 0.2952021  1764         814.4232          9.771876 46.24000
# 6 0.2758855  1681         500.7257         10.029889 25.25063
#   mnAirTemp_lag4_2 mnAirTemp_lag5_2
# 1    NA            17.64000
# 2 59.29            59.29000
# 3 27.04            27.04000
# 4 20.25            20.25000
# 5 31.36            31.36000
# 6 25.00            21.39062

# %% [markdown]
# # Table excluiding year 2002 to test CHL and PP (because values for that year were probably wrong due the iceberg)

# %%
# remove row 5 (year 2002)
testChl <- master_gr [-c(5),]

# %%
head(testChl)
# Out:
#   year intP_RSP mnChl_aw_RSP mnOW_RSP nmSST_aw_RSP intP_MCM  mnChl_aw_MCM
# 1 2003 0.658810 1.278130     190735   -1.047010    0.1797500 0.2424260
# 2 2004 0.659537 1.201000     268734   -0.546599    0.0595893 0.0920093
# 3 2005 0.617897 1.116710     236044   -0.551816    0.2451990 0.5341190
# 4 2006 0.673591 1.344420     218199   -0.970962    0.3927390 0.5908280
# 6 2008 0.525248 0.962226     241795   -0.846050    0.2566900 0.5890600
# 7 2009 0.739713 1.811370     227884   -0.983647    0.4709990 1.1855100
#   mnOW_MCM nmSST_aw_MCM mnAirTemp ⋯ GyreSPD_lag4_2 GyreSPD_lag5_2 Salinity_2
# 1 2701.45  -1.177640    -4.625    ⋯ 33.64          25.00          1213.547
# 2 1115.63  -1.394120    -5.000    ⋯ 32.49          33.64          1213.477
# 3 3630.16  -1.099050    -5.250    ⋯ 39.69          32.49          1210.692
# 4 4718.94  -0.954533    -6.000    ⋯ 38.44          39.69          1211.040
# 6 1968.25  -1.173800    -5.025    ⋯ 51.84          49.00          1212.432
# 7 5003.04  -0.939651    -5.475    ⋯ 60.84          51.84                NA
#   intP_RSP_2 Prop._134_2 TOTALTonnes.100_2 mnSIE_2   mnAirTemp_2
# 1 0.4340306  3025         201.0923          8.173881 21.39062
# 2 0.4349891  1225         426.2491          7.612081 25.00000
# 3 0.3817967  1444        1125.8508          8.020224 27.56250
# 4 0.4537248  2025         729.6968          7.496644 36.00000
# 6 0.2758855  1681         500.7257         10.029889 25.25063
# 7 0.5471753  1764         503.3786          9.431041 29.97562
#   mnAirTemp_lag4_2 mnAirTemp_lag5_2
# 1      NA          17.64000
# 2 59.2900          59.29000
# 3 27.0400          27.04000
# 4 20.2500          20.25000
# 6 25.0000          21.39062
# 7 27.5625          25.00000

# %% [markdown]
# # Plot variables over TIME

# %%
theme_set(theme_bw())

# %%
ggplot(master_gr,aes(x=year,y=SIE_lag5)) + geom_point()
# Out:
# plot without title

# %%
ggplot(master_gr,aes(x=year,y=intP_RSP)) + geom_point()
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(master_gr,aes(x=year,y=mnChl_aw_RSP)) + geom_point()
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(master_gr,aes(x=year,y=mnOW_RSP)) + geom_point()
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(master_gr,aes(x=year,y=nmSST_aw_RSP)) + geom_point()
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(master_gr,aes(x=year,y=mnWind)) + geom_point()
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(master_gr,aes(x=year,y=mnAirTemp)) + geom_point()
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(master_gr,aes(x=year,y=mnSIE)) + geom_point()
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(master_gr,aes(x=year,y=GyreSPD)) + geom_point()
# Out:
# Warning message:
# “Removed 2 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(master_gr,aes(x=year,y=Salinity)) + geom_point()
# Out:
# Warning message:
# “Removed 5 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(master_gr,aes(x=year,y=growth_croz)) + geom_point()
# Out:
# plot without title

# %%
ggplot(master_gr,aes(x=year,y=Prop._134)) + geom_point()
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(master_gr,aes(x=Prop._134,y=growth_croz)) + geom_point()
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# # "in_frame": dataframe only with env. variables (TO USE FOR VIF)
# # NO ICEBERG

# %%
in_frame <- master_gr %>% select (intP_RSP:mnChl_aw_RSP, nmSST_aw_RSP:GyreSPD, Salinity, mnOW_RSP6:SIE_lag5)

# %%
head(in_frame)
# Out:
#   intP_RSP mnChl_aw_RSP nmSST_aw_RSP intP_MCM  mnChl_aw_MCM mnOW_MCM
# 1 0.658810 1.278130     -1.047010    0.1797500 0.2424260    2701.45
# 2 0.659537 1.201000     -0.546599    0.0595893 0.0920093    1115.63
# 3 0.617897 1.116710     -0.551816    0.2451990 0.5341190    3630.16
# 4 0.673591 1.344420     -0.970962    0.3927390 0.5908280    4718.94
# 5 0.543325 1.170400     -1.006890    0.3533950 0.6396110    3903.53
# 6 0.525248 0.962226     -0.846050    0.2566900 0.5890600    1968.25
#   nmSST_aw_MCM mnAirTemp mnWind mnSIE ⋯ mnWind_lag4 mnWind_lag5
# 1 -1.177640    -4.625    8.6    2.859 ⋯ 7.8         7.8
# 2 -1.394120    -5.000    8.4    2.759 ⋯ 7.8         7.8
# 3 -1.099050    -5.250    8.8    2.832 ⋯ 8.6         7.8
# 4 -0.954533    -6.000    8.8    2.738 ⋯ 8.8         8.6
# 5 -1.064650    -6.800    9.4    3.126 ⋯ 8.6         8.8
# 6 -1.173800    -5.025    8.2    3.167 ⋯ 8.4         8.6
#   nmSST_aw_RSP_lag4 nmSST_aw_RSP_lag5 mnAirTemp_lag4 mnAirTemp_lag5
# 1 -0.901666         -0.690398           NA           -4.200
# 2 -0.924639         -0.901666         -7.7           -7.700
# 3 -0.645706         -0.924639         -5.2           -5.200
# 4 -1.117230         -0.645706         -4.5           -4.500
# 5 -1.047010         -1.117230         -5.6           -5.600
# 6 -0.546599         -1.047010         -5.0           -4.625
#   GyreSPD_lag5 GyreSPD_lag4 SIE_lag4 SIE_lag5
# 1 5.0          5.8          2.767    2.600
# 2 5.8          5.7          2.731    2.767
# 3 5.7          6.3          3.123    2.731
# 4 6.3          6.2          2.703    3.123
# 5 6.2          7.0          2.859    2.703
# 6 7.0          7.2          2.759    2.859

# %% [markdown]
# # test without 2002

# %%
in_frame2002 <- testChl %>% select (intP_RSP:mnChl_aw_RSP, nmSST_aw_RSP:GyreSPD, Salinity, mnOW_RSP6:SIE_lag5)

# %% [markdown]
# # ARIMA

# %%
#I included the trace function to understand the combination of p,d,q that arima checked to select the best model#
amdl<-auto.arima(master_gr$growth_croz,ic="aic", trace=TRUE)
# Out:
#  ARIMA(2,0,2) with non-zero mean : Inf
#  ARIMA(0,0,0) with non-zero mean : -1.384252
#  ARIMA(1,0,0) with non-zero mean : -4.529586
#  ARIMA(0,0,1) with non-zero mean : -6.166314
#  ARIMA(0,0,0) with zero mean     : -2.788807
#  ARIMA(1,0,1) with non-zero mean : -4.23597
#  ARIMA(0,0,2) with non-zero mean : Inf
#  ARIMA(1,0,2) with non-zero mean : Inf
#  ARIMA(0,0,1) with zero mean     : -3.662478
#
#  Best model: ARIMA(0,0,1) with non-zero mean

# %%
#checking best model
mdl1<-Arima(master_gr$growth_croz,order=c(1,0,0),include.mean=F,include.drift=T)
summary(mdl1)
# Out:
# Series: master_gr$growth_croz
# ARIMA(1,0,0) with drift
#
# Coefficients:
#           ar1   drift
#       -0.4919  0.0031
# s.e.   0.2439  0.0031
#
# sigma^2 estimated as 0.03936:  log likelihood=4.3
# AIC=-2.6   AICc=-0.76   BIC=-0.1
#
# Training set error measures:
#                      ME      RMSE       MAE  MPE MAPE      MASE         ACF1
# Training set 0.02206329 0.1863614 0.1299614 -Inf  Inf 0.6518501 -0.005703827

# %%
checkresiduals(mdl1)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from ARIMA(1,0,0) with drift
# Q* = 6.3256, df = 3, p-value = 0.0968
#
# Model df: 2.   Total lags used: 5
# plot without title

# %%
# Compare to:
mdl1a<-Arima(master_gr$growth_croz,order=c(2,0,0),include.mean=F,include.drift=T)
summary(mdl1a)
# Out:
# Series: master_gr$growth_croz
# ARIMA(2,0,0) with drift
#
# Coefficients:
#           ar1      ar2   drift
#       -0.5079  -0.2469  0.0030
# s.e.   0.2489   0.3604  0.0026
#
# sigma^2 estimated as 0.04097:  log likelihood=4.53
# AIC=-1.06   AICc=2.27   BIC=2.27
#
# Training set error measures:
#                      ME      RMSE       MAE  MPE MAPE      MASE        ACF1
# Training set 0.02739753 0.1836951 0.1272164 -Inf  Inf 0.6380823 -0.02928708

# %%
checkresiduals(mdl1a)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from ARIMA(2,0,0) with drift
# Q* = 4.6634, df = 3, p-value = 0.1982
#
# Model df: 3.   Total lags used: 6
# plot without title

# %%
autoplot(forecast(mdl1))
# Out:
# plot without title

# %% [markdown]
# # Plotting the correct trend

# %%
adcroz<-master_gr$growth_croz
names(adcroz)<-master_gr$year

# %%
# Uncorrected trend
ggtsdisplay(adcroz)
# Out:
# plot without title

# %%
pdf<-data.frame(year=master_gr$year,uncorr=mdl1$x,corr=fitted(mdl1))
ggplot(pdf,aes(x=year,y=uncorr)) + geom_point() + geom_line(aes(y=corr),color="blue")
# Out:
# plot without title

# %%
save(adcroz,pdf,file="/home/ubuntu/Workspace/Anthropocene/data/bestModeldata.RData")

# %% [markdown]
# # Playing around with the covariates

# %% [markdown]
# ## Removing drift term and including (1,0,0) structure

# %% [markdown]
# ## 1st: VIF to select the environmental variables to include in the saturated model

# %%
#threshold at 10 (it’s equivalent to explaining 99% of the information in a variable by the set of the other covariates).

#select covariates based on variance inflation

vif_func<-function(in_frame,thresh=10,trace=T,...){
  
  
  
  if(class(in_frame) != 'data.frame') in_frame<-data.frame(in_frame)
  
  
  
  #get initial vif value for all comparisons of variables
  
  vif_init<-NULL
  
  var_names <- names(in_frame)
  
  for(val in var_names){
    
    regressors <- var_names[-which(var_names == val)]
    
    form <- paste(regressors, collapse = '+')
    
    form_in <- formula(paste(val, '~', form))
    
    vif_init<-rbind(vif_init, c(val, VIF(lm(form_in, data = in_frame, ...))))
    
  }
  
  vif_max<-max(as.numeric(vif_init[,2]), na.rm = TRUE)
  
  
  
  if(vif_max < thresh){
    
    if(trace==T){ #print output of each iteration
      
      prmatrix(vif_init,collab=c('var','vif'),rowlab=rep('',nrow(vif_init)),quote=F)
      
      cat('\n')
      
      cat(paste('All variables have VIF < ', thresh,', max VIF ',round(vif_max,2), sep=''),'\n\n')
      
    }
    
    return(var_names)
    
  }
  
  else{
    
    
    
    in_dat<-in_frame
    
    
    
    #backwards selection of explanatory variables, stops when all VIF values are below 'thresh'
    
    while(vif_max >= thresh){
      
      
      
      vif_vals<-NULL
      
      var_names <- names(in_dat)
      
      
      
      for(val in var_names){
        
        regressors <- var_names[-which(var_names == val)]
        
        form <- paste(regressors, collapse = '+')
        
        form_in <- formula(paste(val, '~', form))
        
        vif_add<-VIF(lm(form_in, data = in_dat, ...))
        
        vif_vals<-rbind(vif_vals,c(val,vif_add))
        
      }
      
      max_row<-which(vif_vals[,2] == max(as.numeric(vif_vals[,2]), na.rm = TRUE))[1]
      
      
      
      vif_max<-as.numeric(vif_vals[max_row,2])
      
      
      
      if(vif_max<thresh) break
      
      
      
      if(trace==T){ #print output of each iteration
        
        prmatrix(vif_vals,collab=c('var','vif'),rowlab=rep('',nrow(vif_vals)),quote=F)
        
        cat('\n')
        
        cat('removed: ',vif_vals[max_row,1],vif_max,'\n\n')
        
        flush.console()
        
      }
      
      
      
      in_dat<-in_dat[,!names(in_dat) %in% vif_vals[max_row,1]]
      
      
      
    }
    
    
    
    return(names(in_dat))
    
    
    
  }
  
  
  
}
  
vif_func(in_frame,thresh=10,trace=T)
# Out:
#  var               vif
#  intP_RSP          Inf
#  mnChl_aw_RSP      Inf
#  nmSST_aw_RSP      Inf
#  intP_MCM          Inf
#  mnChl_aw_MCM      Inf
#  mnOW_MCM          Inf
#  nmSST_aw_MCM      Inf
#  mnAirTemp         Inf
#  mnWind            Inf
#  mnSIE             Inf
#  GyreSPD           Inf
#  Salinity          Inf
#  mnOW_RSP6         Inf
#  SIE_lag5_2        Inf
#  SIE_lag4_2        Inf
#  mnWind_lag4       Inf
#  mnWind_lag5       Inf
#  nmSST_aw_RSP_lag4 Inf
#  nmSST_aw_RSP_lag5 Inf
#  mnAirTemp_lag4    Inf
#  mnAirTemp_lag5    Inf
#  GyreSPD_lag5      Inf
#  GyreSPD_lag4      Inf
#  SIE_lag4          Inf
#  SIE_lag5          Inf
#
# removed:  intP_RSP Inf
#
#  var               vif
#  mnChl_aw_RSP      Inf
#  nmSST_aw_RSP      Inf
#  intP_MCM          Inf
#  mnChl_aw_MCM      Inf
#  mnOW_MCM          Inf
#  nmSST_aw_MCM      Inf
#  mnAirTemp         Inf
#  mnWind            Inf
#  mnSIE             Inf
#  GyreSPD           Inf
#  Salinity          Inf
#  mnOW_RSP6         Inf
#  SIE_lag5_2        Inf
#  SIE_lag4_2        Inf
#  mnWind_lag4       Inf
#  mnWind_lag5       Inf
#  nmSST_aw_RSP_lag4 Inf
#  nmSST_aw_RSP_lag5 Inf
#  mnAirTemp_lag4    Inf
#  mnAirTemp_lag5    Inf
#  GyreSPD_lag5      Inf
#  GyreSPD_lag4      Inf
#  SIE_lag4          Inf
#  SIE_lag5          Inf
#
# removed:  mnChl_aw_RSP Inf
#
#  var               vif
#  nmSST_aw_RSP      Inf
#  intP_MCM          Inf
#  mnChl_aw_MCM      Inf
#  mnOW_MCM          Inf
#  nmSST_aw_MCM      Inf
#  mnAirTemp         Inf
#  mnWind            Inf
#  mnSIE             Inf
#  GyreSPD           Inf
#  Salinity          Inf
#  mnOW_RSP6         Inf
#  SIE_lag5_2        Inf
#  SIE_lag4_2        Inf
#  mnWind_lag4       Inf
#  mnWind_lag5       Inf
#  nmSST_aw_RSP_lag4 Inf
#  nmSST_aw_RSP_lag5 Inf
#  mnAirTemp_lag4    Inf
#  mnAirTemp_lag5    Inf
#  GyreSPD_lag5      Inf
#  GyreSPD_lag4      Inf
#  SIE_lag4          Inf
#  SIE_lag5          Inf
#
# removed:  nmSST_aw_RSP Inf
#
#  var               vif
#  intP_MCM          Inf
#  mnChl_aw_MCM      Inf
#  mnOW_MCM          Inf
#  nmSST_aw_MCM      Inf
#  mnAirTemp         Inf
#  mnWind            Inf
#  mnSIE             Inf
#  GyreSPD           Inf
#  Salinity          Inf
#  mnOW_RSP6         Inf
#  SIE_lag5_2        Inf
#  SIE_lag4_2        Inf
#  mnWind_lag4       Inf
#  mnWind_lag5       Inf
#  nmSST_aw_RSP_lag4 Inf
#  nmSST_aw_RSP_lag5 Inf
#  mnAirTemp_lag4    Inf
#  mnAirTemp_lag5    Inf
#  GyreSPD_lag5      Inf
#  GyreSPD_lag4      Inf
#  SIE_lag4          Inf
#  SIE_lag5          Inf
#
# removed:  intP_MCM Inf
#
#  var               vif
#  mnChl_aw_MCM      Inf
#  mnOW_MCM          Inf
#  nmSST_aw_MCM      Inf
#  mnAirTemp         Inf
#  mnWind            Inf
#  mnSIE             Inf
#  GyreSPD           Inf
#  Salinity          Inf
#  mnOW_RSP6         Inf
#  SIE_lag5_2        Inf
#  SIE_lag4_2        Inf
#  mnWind_lag4       Inf
#  mnWind_lag5       Inf
#  nmSST_aw_RSP_lag4 Inf
#  nmSST_aw_RSP_lag5 Inf
#  mnAirTemp_lag4    Inf
#  mnAirTemp_lag5    Inf
#  GyreSPD_lag5      Inf
#  GyreSPD_lag4      Inf
#  SIE_lag4          Inf
#  SIE_lag5          Inf
#
# removed:  mnChl_aw_MCM Inf
#
#  var               vif
#  mnOW_MCM          Inf
#  nmSST_aw_MCM      Inf
#  mnAirTemp         Inf
#  mnWind            Inf
#  mnSIE             Inf
#  GyreSPD           Inf
#  Salinity          Inf
#  mnOW_RSP6         Inf
#  SIE_lag5_2        Inf
#  SIE_lag4_2        Inf
#  mnWind_lag4       Inf
#  mnWind_lag5       Inf
#  nmSST_aw_RSP_lag4 Inf
#  nmSST_aw_RSP_lag5 Inf
#  mnAirTemp_lag4    Inf
#  mnAirTemp_lag5    Inf
#  GyreSPD_lag5      Inf
#  GyreSPD_lag4      Inf
#  SIE_lag4          Inf
#  SIE_lag5          Inf
#
# removed:  mnOW_MCM Inf
#
#  var               vif
#  nmSST_aw_MCM      Inf
#  mnAirTemp         Inf
#  mnWind            Inf
#  mnSIE             Inf
#  GyreSPD           Inf
#  Salinity          Inf
#  mnOW_RSP6         Inf
#  SIE_lag5_2        Inf
#  SIE_lag4_2        Inf
#  mnWind_lag4       Inf
#  mnWind_lag5       Inf
#  nmSST_aw_RSP_lag4 Inf
#  nmSST_aw_RSP_lag5 Inf
#  mnAirTemp_lag4    Inf
#  mnAirTemp_lag5    Inf
#  GyreSPD_lag5      Inf
#  GyreSPD_lag4      Inf
#  SIE_lag4          Inf
#  SIE_lag5          Inf
#
# removed:  nmSST_aw_MCM Inf
#
#  var               vif
#  mnAirTemp         Inf
#  mnWind            Inf
#  mnSIE             Inf
#  GyreSPD           Inf
#  Salinity          Inf
#  mnOW_RSP6         Inf
#  SIE_lag5_2        Inf
#  SIE_lag4_2        Inf
#  mnWind_lag4       Inf
#  mnWind_lag5       Inf
#  nmSST_aw_RSP_lag4 Inf
#  nmSST_aw_RSP_lag5 Inf
#  mnAirTemp_lag4    Inf
#  mnAirTemp_lag5    Inf
#  GyreSPD_lag5      Inf
#  GyreSPD_lag4      Inf
#  SIE_lag4          Inf
#  SIE_lag5          Inf
#
# removed:  mnAirTemp Inf
#
#  var               vif
#  mnWind            Inf
#  mnSIE             Inf
#  GyreSPD           Inf
#  Salinity          Inf
#  mnOW_RSP6         Inf
#  SIE_lag5_2        Inf
#  SIE_lag4_2        Inf
#  mnWind_lag4       Inf
#  mnWind_lag5       Inf
#  nmSST_aw_RSP_lag4 Inf
#  nmSST_aw_RSP_lag5 Inf
#  mnAirTemp_lag4    Inf
#  mnAirTemp_lag5    Inf
#  GyreSPD_lag5      Inf
#  GyreSPD_lag4      Inf
#  SIE_lag4          Inf
#  SIE_lag5          Inf
#
# removed:  mnWind Inf
#
#  var               vif
#  mnSIE             Inf
#  GyreSPD           Inf
#  Salinity          Inf
#  mnOW_RSP6         Inf
#  SIE_lag5_2        Inf
#  SIE_lag4_2        Inf
#  mnWind_lag4       Inf
#  mnWind_lag5       Inf
#  nmSST_aw_RSP_lag4 Inf
#  nmSST_aw_RSP_lag5 Inf
#  mnAirTemp_lag4    Inf
#  mnAirTemp_lag5    Inf
#  GyreSPD_lag5      Inf
#  GyreSPD_lag4      Inf
#  SIE_lag4          Inf
#  SIE_lag5          Inf
#
# removed:  mnSIE Inf
#
#  var               vif
#  GyreSPD           Inf
#  Salinity          Inf
#  mnOW_RSP6         Inf
#  SIE_lag5_2        Inf
#  SIE_lag4_2        Inf
#  mnWind_lag4       Inf
#  mnWind_lag5       Inf
#  nmSST_aw_RSP_lag4 Inf
#  nmSST_aw_RSP_lag5 Inf
#  mnAirTemp_lag4    Inf
#  mnAirTemp_lag5    Inf
#  GyreSPD_lag5      Inf
#  GyreSPD_lag4      Inf
#  SIE_lag4          Inf
#  SIE_lag5          Inf
#
# removed:  GyreSPD Inf
#
#  var               vif
#  Salinity          Inf
#  mnOW_RSP6         Inf
#  SIE_lag5_2        Inf
#  SIE_lag4_2        Inf
#  mnWind_lag4       Inf
#  mnWind_lag5       Inf
#  nmSST_aw_RSP_lag4 Inf
#  nmSST_aw_RSP_lag5 Inf
#  mnAirTemp_lag4    Inf
#  mnAirTemp_lag5    Inf
#  GyreSPD_lag5      Inf
#  GyreSPD_lag4      Inf
#  SIE_lag4          Inf
#  SIE_lag5          Inf
#
# removed:  Salinity Inf
#
#  var               vif
#  mnOW_RSP6         5.94415830038634
#  SIE_lag5_2        72706.8696088114
#  SIE_lag4_2        11124.2443114456
#  mnWind_lag4       27.7370605306187
#  mnWind_lag5       6.15104381729262
#  nmSST_aw_RSP_lag4 45.8990267281356
#  nmSST_aw_RSP_lag5 3.6564127478123
#  mnAirTemp_lag4    69.1232628529163
#  mnAirTemp_lag5    85.2952556655877
#  GyreSPD_lag5      2.23678452034532
#  GyreSPD_lag4      46.1708931917096
#  SIE_lag4          10458.2429528916
#  SIE_lag5          72230.4791326079
#
# removed:  SIE_lag5_2 72706.87
#
#  var               vif
#  mnOW_RSP6         5.73663767701223
#  SIE_lag4_2        7917.44726841543
#  mnWind_lag4       16.9731278103181
#  mnWind_lag5       2.87572753953657
#  nmSST_aw_RSP_lag4 5.7692072392121
#  nmSST_aw_RSP_lag5 3.42305023848888
#  mnAirTemp_lag4    32.2416809661081
#  mnAirTemp_lag5    33.7707249014089
#  GyreSPD_lag5      2.17593600430986
#  GyreSPD_lag4      8.26684806156563
#  SIE_lag4          7853.65144028337
#  SIE_lag5          3.98882044992121
#
# removed:  SIE_lag4_2 7917.447
#
#  var               vif
#  mnOW_RSP6         5.72592631836889
#  mnWind_lag4       16.9728881384817
#  mnWind_lag5       2.87547375729564
#  nmSST_aw_RSP_lag4 5.48531309715414
#  nmSST_aw_RSP_lag5 3.42304344348699
#  mnAirTemp_lag4    30.6796455403501
#  mnAirTemp_lag5    31.8036505091612
#  GyreSPD_lag5      2.15745744835417
#  GyreSPD_lag4      6.19076304283895
#  SIE_lag4          9.94404987848813
#  SIE_lag5          3.91267665556551
#
# removed:  mnAirTemp_lag5 31.80365
#  [1] "mnOW_RSP6"         "mnWind_lag4"       "mnWind_lag5"
#  [4] "nmSST_aw_RSP_lag4" "nmSST_aw_RSP_lag5" "mnAirTemp_lag4"
#  [7] "GyreSPD_lag5"      "GyreSPD_lag4"      "SIE_lag4"
# [10] "SIE_lag5"

# %% [markdown]
# # Chl, and Productivity showed up as redundant variables, so I don't include them in the saturated model, specially because how difficult is to give a rationale to link productivity with anything at the Ross Sea

# %% [markdown]
# # Saturated model

# %%
cov_sat_growth<-as.matrix(master_gr[,c("av_SIE", "GyreSPD", 
                              "mnWind",  "nmSST_aw_RSP",  "Fish_cum3",
                                       "mnAirTemp", "mnOW_RSP6")]) #"SIE_lag5", "nmSST_aw_RSP_lag5", , "mnOW_RSP6_lag5" "mnAirTemp_lag5","GyreSPD_lag5","mnWind_lag5",
mdlsat<-Arima(master_gr$growth_croz,order=c(1,0,0),include.mean=F,include.drift=F,xreg= cov_sat_growth)
summary(mdlsat)
# Out:
# Series: master_gr$growth_croz
# Regression with ARIMA(1,0,0) errors
#
# Coefficients:
#           ar1  av_SIE  GyreSPD   mnWind  nmSST_aw_RSP  Fish_cum3  mnAirTemp
#       -0.8732  0.1445   0.1177  -0.0195        0.6685     0.0088     0.0113
# s.e.   0.1239  0.1476   0.0433   0.0680        0.2230     0.0041     0.0461
#       mnOW_RSP6
#         -2.5203
# s.e.     1.3267
#
# sigma^2 estimated as 0.03248:  log likelihood=9.42
# AIC=-0.84   AICc=35.16   BIC=5.54
#
# Training set error measures:
#                        ME      RMSE       MAE       MPE     MAPE      MASE
# Training set -0.009713939 0.1231075 0.1018462 -133.4281 356.8421 0.5108322
#                   ACF1
# Training set -0.541252

# %%
coeftest(mdlsat)
# Out:
# z test of coefficients:
#
#                Estimate Std. Error z value  Pr(>|z|)
# ar1          -0.8732311  0.1238584 -7.0502 1.786e-12 ***
# av_SIE        0.1444807  0.1475503  0.9792  0.327483
# GyreSPD       0.1177326  0.0432607  2.7215  0.006499 **
# mnWind       -0.0195230  0.0680083 -0.2871  0.774060
# nmSST_aw_RSP  0.6685350  0.2230356  2.9974  0.002723 **
# Fish_cum3     0.0088204  0.0040501  2.1779  0.029417 *
# mnAirTemp     0.0112989  0.0461293  0.2449  0.806503
# mnOW_RSP6    -2.5202595  1.3267465 -1.8996  0.057488 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # Including lags

# %%
#"SIE_lag5"
cov_sat_growth<-as.matrix(master_gr[,c("av_SIE","SIE_lag5", "GyreSPD", 
                              "mnWind",  "nmSST_aw_RSP",  "Fish_cum3",
                                       "mnAirTemp", "mnOW_RSP6")]) # "nmSST_aw_RSP_lag5", , "mnOW_RSP6_lag5" "mnAirTemp_lag5","GyreSPD_lag5","mnWind_lag5",
mdlsat<-Arima(master_gr$growth_croz,order=c(1,0,0),include.mean=F,include.drift=F,xreg= cov_sat_growth)
summary(mdlsat)
# Out:
# Series: master_gr$growth_croz
# Regression with ARIMA(1,0,0) errors
#
# Coefficients:
#           ar1  av_SIE  SIE_lag5  GyreSPD  mnWind  nmSST_aw_RSP  Fish_cum3
#       -0.8483  0.1788   -0.1716   0.0718  0.0466        0.7347     0.0085
# s.e.   0.1438  0.1532    0.2248   0.0741  0.1096        0.2374     0.0040
#       mnAirTemp  mnOW_RSP6
#          0.0285    -1.3805
# s.e.     0.0511     2.0021
#
# sigma^2 estimated as 0.03686:  log likelihood=9.71
# AIC=0.58   AICc=55.58   BIC=7.66
#
# Training set error measures:
#                        ME      RMSE        MAE       MPE     MAPE      MASE
# Training set -0.009007277 0.1214173 0.09851552 -46.33804 288.1907 0.4941264
#                    ACF1
# Training set -0.5187804

# %%
coeftest(mdlsat)
# Out:
# z test of coefficients:
#
#                Estimate Std. Error z value  Pr(>|z|)
# ar1          -0.8482787  0.1438488 -5.8970 3.701e-09 ***
# av_SIE        0.1788129  0.1531883  1.1673  0.243099
# SIE_lag5     -0.1716481  0.2248292 -0.7635  0.445189
# GyreSPD       0.0718204  0.0741048  0.9692  0.332458
# mnWind        0.0465919  0.1096447  0.4249  0.670884
# nmSST_aw_RSP  0.7346512  0.2373657  3.0950  0.001968 **
# Fish_cum3     0.0084796  0.0040469  2.0953  0.036142 *
# mnAirTemp     0.0284731  0.0511188  0.5570  0.577528
# mnOW_RSP6    -1.3804992  2.0021166 -0.6895  0.490496
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
#SIE_lag4",
cov_sat_growth<-as.matrix(master_gr[,c("av_SIE", "SIE_lag4", "GyreSPD", 
                              "mnWind",  "nmSST_aw_RSP",  "Fish_cum3",
                                       "mnAirTemp", "mnOW_RSP6")]) #"SIE_lag5", "nmSST_aw_RSP_lag5", , "mnOW_RSP6_lag5" "mnAirTemp_lag5","GyreSPD_lag5","mnWind_lag5",
mdlsat<-Arima(master_gr$growth_croz,order=c(1,0,0),include.mean=F,include.drift=F,xreg= cov_sat_growth)
summary(mdlsat)
# Out:
# Series: master_gr$growth_croz
# Regression with ARIMA(1,0,0) errors
#
# Coefficients:
#           ar1  av_SIE  SIE_lag4  GyreSPD  mnWind  nmSST_aw_RSP  Fish_cum3
#       -0.8279  0.1445   -0.1909   0.0757  0.0302        0.6718     0.0089
# s.e.   0.1558  0.1451    0.1701   0.0574  0.0804        0.2176     0.0040
#       mnAirTemp  mnOW_RSP6
#          0.0302    -0.4127
# s.e.     0.0485     2.3063
#
# sigma^2 estimated as 0.03548:  log likelihood=10.05
# AIC=-0.1   AICc=54.9   BIC=6.98
#
# Training set error measures:
#                        ME      RMSE        MAE      MPE     MAPE      MASE
# Training set -0.007873815 0.1191233 0.09873171 50.36614 206.2552 0.4952108
#                    ACF1
# Training set -0.5272981

# %%
coeftest(mdlsat)
# Out:
# z test of coefficients:
#
#                Estimate Std. Error z value Pr(>|z|)
# ar1          -0.8279281  0.1558410 -5.3126 1.08e-07 ***
# av_SIE        0.1444572  0.1451181  0.9954 0.319520
# SIE_lag4     -0.1908658  0.1700563 -1.1224 0.261706
# GyreSPD       0.0757201  0.0573702  1.3199 0.186885
# mnWind        0.0301958  0.0803583  0.3758 0.707092
# nmSST_aw_RSP  0.6717714  0.2176086  3.0871 0.002021 **
# Fish_cum3     0.0089357  0.0039668  2.2526 0.024285 *
# mnAirTemp     0.0302063  0.0485163  0.6226 0.533546
# mnOW_RSP6    -0.4126517  2.3062951 -0.1789 0.857997
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
#SIE_lag4", "nmSST_aw_RSP_lag5" and "nmSST_aw_RSP_lag4",,
cov_sat_growth<-as.matrix(master_gr[,c("av_SIE", "SIE_lag4", "GyreSPD", 
                              "mnWind",  "nmSST_aw_RSP", "nmSST_aw_RSP_lag4", "Fish_cum3",
                                       "mnAirTemp", "mnOW_RSP6")]) #"SIE_lag5", "nmSST_aw_RSP_lag5", , "mnOW_RSP6_lag5" "mnAirTemp_lag5","GyreSPD_lag5","mnWind_lag5",
mdlsat<-Arima(master_gr$growth_croz,order=c(1,0,0),include.mean=F,include.drift=F,xreg= cov_sat_growth)
summary(mdlsat)
# Out:
# Series: master_gr$growth_croz
# Regression with ARIMA(1,0,0) errors
#
# Coefficients:
#           ar1  av_SIE  SIE_lag4  GyreSPD  mnWind  nmSST_aw_RSP
#       -0.8139   0.113   -0.1846   0.0612  0.0541        0.6593
# s.e.   0.1650   0.154    0.1699   0.0631  0.0903        0.2175
#       nmSST_aw_RSP_lag4  Fish_cum3  mnAirTemp  mnOW_RSP6
#                  0.0970     0.0090     0.0354    -0.1774
# s.e.             0.1706     0.0039     0.0491     2.3417
#
# sigma^2 estimated as 0.04186:  log likelihood=10.21
# AIC=1.57   AICc=89.57   BIC=9.36
#
# Training set error measures:
#                        ME      RMSE     MAE      MPE     MAPE      MASE
# Training set -0.007330365 0.1181207 0.09946 3.774962 253.8188 0.4988637
#                   ACF1
# Training set -0.467067

# %%
coeftest(mdlsat)
# Out:
# z test of coefficients:
#
#                     Estimate Std. Error z value Pr(>|z|)
# ar1               -0.8138844  0.1650456 -4.9313 8.17e-07 ***
# av_SIE             0.1129632  0.1540462  0.7333  0.46337
# SIE_lag4          -0.1846195  0.1698518 -1.0869  0.27706
# GyreSPD            0.0612160  0.0630900  0.9703  0.33190
# mnWind             0.0541246  0.0902547  0.5997  0.54871
# nmSST_aw_RSP       0.6593283  0.2175478  3.0307  0.00244 **
# nmSST_aw_RSP_lag4  0.0969844  0.1705556  0.5686  0.56960
# Fish_cum3          0.0090140  0.0039455  2.2846  0.02233 *
# mnAirTemp          0.0353778  0.0491445  0.7199  0.47160
# mnOW_RSP6         -0.1774086  2.3417428 -0.0758  0.93961
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
#"mnAirTemp_lag5" and "mnAirTemp_lag4"
cov_sat_growth<-as.matrix(master_gr[,c("av_SIE", "SIE_lag4", "GyreSPD", 
                              "mnWind",  "nmSST_aw_RSP", "Fish_cum3",
                                       "mnAirTemp", "mnAirTemp_lag5", "mnOW_RSP6")]) #"SIE_lag5", "nmSST_aw_RSP_lag5", , "mnOW_RSP6_lag5" "mnAirTemp_lag5","GyreSPD_lag5","mnWind_lag5",
mdlsat<-Arima(master_gr$growth_croz,order=c(1,0,0),include.mean=F,include.drift=F,xreg= cov_sat_growth)
summary(mdlsat)
# Out:
# Series: master_gr$growth_croz
# Regression with ARIMA(1,0,0) errors
#
# Coefficients:
#           ar1  av_SIE  SIE_lag4  GyreSPD  mnWind  nmSST_aw_RSP  Fish_cum3
#       -0.7619  0.0603   -0.3762   0.0477  0.0510        0.6141     0.0081
# s.e.   0.2035  0.1461    0.1808   0.0548  0.0743        0.2006     0.0036
#       mnAirTemp  mnAirTemp_lag5  mnOW_RSP6
#          0.0009         -0.0705     0.5541
# s.e.     0.0466          0.0365     2.1557
#
# sigma^2 estimated as 0.03403:  log likelihood=11.88
# AIC=-1.75   AICc=86.25   BIC=6.04
#
# Training set error measures:
#                        ME   RMSE        MAE      MPE    MAPE     MASE
# Training set -0.005851257 0.1065 0.07886164 272.4651 308.738 0.395548
#                    ACF1
# Training set -0.4830614

# %%
coeftest(mdlsat)
# Out:
# z test of coefficients:
#
#                   Estimate  Std. Error z value Pr(>|z|)
# ar1            -0.76187464  0.20348518 -3.7441 0.000181 ***
# av_SIE          0.06026108  0.14611364  0.4124 0.680027
# SIE_lag4       -0.37620140  0.18081046 -2.0806 0.037467 *
# GyreSPD         0.04770517  0.05477272  0.8710 0.383773
# mnWind          0.05102516  0.07428855  0.6869 0.492177
# nmSST_aw_RSP    0.61408395  0.20061684  3.0610 0.002206 **
# Fish_cum3       0.00811313  0.00363741  2.2305 0.025716 *
# mnAirTemp       0.00091895  0.04659512  0.0197 0.984265
# mnAirTemp_lag5 -0.07051389  0.03653622 -1.9300 0.053610 .
# mnOW_RSP6       0.55410360  2.15565915  0.2570 0.797143
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
#"mnOW_RSP6_lag5" and "mnOW_RSP6_lag4" 
cov_sat_growth<-as.matrix(master_gr[,c("av_SIE", "SIE_lag4", "GyreSPD", 
                              "mnWind",  "nmSST_aw_RSP", "Fish_cum3",
                                       "mnAirTemp_lag5", "mnOW_RSP6", "mnOW_RSP6_lag5")]) #"SIE_lag5", "nmSST_aw_RSP_lag5", ,"GyreSPD_lag5","mnWind_lag5",
mdlsat<-Arima(master_gr$growth_croz,order=c(1,0,0),include.mean=F,include.drift=F,xreg= cov_sat_growth)
summary(mdlsat)
# Out:
# Series: master_gr$growth_croz
# Regression with ARIMA(1,0,0) errors
#
# Coefficients:
#           ar1  av_SIE  SIE_lag4  GyreSPD  mnWind  nmSST_aw_RSP  Fish_cum3
#       -0.8132  0.0645   -0.3518   0.0534  0.0337        0.6479     0.0102
# s.e.   0.1909  0.1359    0.1708   0.0499  0.0570        0.1789     0.0036
#       mnAirTemp_lag5  mnOW_RSP6  mnOW_RSP6_lag5
#              -0.0754    -0.5608          1.0664
# s.e.          0.0324     2.1526          0.7720
#
# sigma^2 estimated as 0.02988:  log likelihood=12.74
# AIC=-3.49   AICc=84.51   BIC=4.3
#
# Training set error measures:
#                        ME      RMSE        MAE     MPE     MAPE      MASE
# Training set -0.006349648 0.0998003 0.08082599 113.706 179.6476 0.4054007
#                    ACF1
# Training set -0.4316947

# %%
coeftest(mdlsat)
# Out:
# z test of coefficients:
#
#                  Estimate Std. Error z value  Pr(>|z|)
# ar1            -0.8131923  0.1909332 -4.2590 2.053e-05 ***
# av_SIE          0.0645008  0.1359300  0.4745 0.6351331
# SIE_lag4       -0.3518329  0.1708374 -2.0595 0.0394502 *
# GyreSPD         0.0533639  0.0499240  1.0689 0.2851141
# mnWind          0.0337172  0.0569602  0.5919 0.5538886
# nmSST_aw_RSP    0.6478877  0.1788534  3.6225 0.0002918 ***
# Fish_cum3       0.0102070  0.0036061  2.8304 0.0046483 **
# mnAirTemp_lag5 -0.0754113  0.0323871 -2.3284 0.0198889 *
# mnOW_RSP6      -0.5608006  2.1525927 -0.2605 0.7944601
# mnOW_RSP6_lag5  1.0664096  0.7719861  1.3814 0.1671608
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# removing SIE(NO LAG) AND AIR TEMP (NO LAG)
cov_sat_growth<-as.matrix(master_gr[,c("SIE_lag4", "GyreSPD", 
                              "mnWind",  "nmSST_aw_RSP", "Fish_cum3",
                                       "mnAirTemp_lag5", "mnOW_RSP6")]) #"SIE_lag5", "nmSST_aw_RSP_lag5", ,"GyreSPD_lag5","mnWind_lag5",
mdlsat<-Arima(master_gr$growth_croz,order=c(1,0,0),include.mean=F,include.drift=F,xreg= cov_sat_growth)
summary(mdlsat)
# Out:
# Series: master_gr$growth_croz
# Regression with ARIMA(1,0,0) errors
#
# Coefficients:
#           ar1  SIE_lag4  GyreSPD  mnWind  nmSST_aw_RSP  Fish_cum3
#       -0.7234   -0.3937   0.0422  0.0674        0.6019     0.0087
# s.e.   0.1999    0.1753   0.0522  0.0424        0.1967     0.0033
#       mnAirTemp_lag5  mnOW_RSP6
#              -0.0763     0.7972
# s.e.          0.0332     2.0722
#
# sigma^2 estimated as 0.02478:  log likelihood=11.79
# AIC=-5.59   AICc=30.41   BIC=0.78
#
# Training set error measures:
#                        ME     RMSE        MAE     MPE     MAPE      MASE
# Training set -0.005198917 0.107534 0.07707634 352.206 377.6368 0.3865935
#                    ACF1
# Training set -0.4322949

# %%
coeftest(mdlsat)
# Out:
# z test of coefficients:
#
#                  Estimate Std. Error z value  Pr(>|z|)
# ar1            -0.7233887  0.1999120 -3.6185 0.0002963 ***
# SIE_lag4       -0.3937132  0.1752655 -2.2464 0.0246796 *
# GyreSPD         0.0422154  0.0521971  0.8088 0.4186482
# mnWind          0.0674150  0.0424416  1.5884 0.1121924
# nmSST_aw_RSP    0.6018531  0.1966741  3.0602 0.0022122 **
# Fish_cum3       0.0086895  0.0033000  2.6331 0.0084598 **
# mnAirTemp_lag5 -0.0762948  0.0332114 -2.2972 0.0216049 *
# mnOW_RSP6       0.7972046  2.0722463  0.3847 0.7004556
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
#INCLUDING GYRE LAG
cov_sat_growth<-as.matrix(master_gr[,c("SIE_lag4", "GyreSPD", "GyreSPD_lag4",
                              "mnWind",  "nmSST_aw_RSP", "Fish_cum3",
                                       "mnAirTemp_lag5", "mnOW_RSP6")]) 
mdlsat<-Arima(master_gr$growth_croz,order=c(1,0,0),include.mean=F,include.drift=F,xreg= cov_sat_growth)
summary(mdlsat)
# Out:
# Series: master_gr$growth_croz
# Regression with ARIMA(1,0,0) errors
#
# Coefficients:
#           ar1  SIE_lag4  GyreSPD  GyreSPD_lag4  mnWind  nmSST_aw_RSP  Fish_cum3
#       -0.8523   -0.4391   0.0505        0.0714  0.0174        0.5465     0.0058
# s.e.   0.1420    0.1410   0.0402        0.0247  0.0366        0.1515     0.0027
#       mnAirTemp_lag5  mnOW_RSP6
#              -0.0799     1.1228
# s.e.          0.0250     1.6624
#
# sigma^2 estimated as 0.01844:  log likelihood=14.89
# AIC=-9.78   AICc=45.22   BIC=-2.7
#
# Training set error measures:
#                        ME       RMSE        MAE      MPE    MAPE      MASE
# Training set -0.005497685 0.08589009 0.06755615 113.2416 195.978 0.3388429
#                   ACF1
# Training set -0.510716

# %%
coeftest(mdlsat)
# Out:
# z test of coefficients:
#
#                  Estimate Std. Error z value  Pr(>|z|)
# ar1            -0.8522732  0.1420244 -6.0009 1.962e-09 ***
# SIE_lag4       -0.4390809  0.1410189 -3.1136  0.001848 **
# GyreSPD         0.0504633  0.0401544  1.2567  0.208850
# GyreSPD_lag4    0.0713815  0.0246857  2.8916  0.003833 **
# mnWind          0.0173505  0.0365522  0.4747  0.635017
# nmSST_aw_RSP    0.5465334  0.1514930  3.6076  0.000309 ***
# Fish_cum3       0.0057823  0.0027000  2.1416  0.032229 *
# mnAirTemp_lag5 -0.0798830  0.0249914 -3.1964  0.001391 **
# mnOW_RSP6       1.1227565  1.6623686  0.6754  0.499424
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
cov_sat_growth<-as.matrix(master_gr[,c("SIE_lag4", "GyreSPD", "GyreSPD_lag4",
                                "nmSST_aw_RSP", "Fish_cum3",
                                       "mnAirTemp_lag5", "mnOW_RSP6")]) 
mdlsat<-Arima(master_gr$growth_croz,order=c(1,0,0),include.mean=F,include.drift=F,xreg= cov_sat_growth)
summary(mdlsat)
# Out:
# Series: master_gr$growth_croz
# Regression with ARIMA(1,0,0) errors
#
# Coefficients:
#           ar1  SIE_lag4  GyreSPD  GyreSPD_lag4  nmSST_aw_RSP  Fish_cum3
#       -0.8689   -0.4044   0.0610        0.0762        0.5139     0.0056
# s.e.   0.1268    0.1205   0.0332        0.0225        0.1349     0.0027
#       mnAirTemp_lag5  mnOW_RSP6
#              -0.0765     0.9042
# s.e.          0.0239     1.5935
#
# sigma^2 estimated as 0.01593:  log likelihood=14.77
# AIC=-11.55   AICc=24.45   BIC=-5.18
#
# Training set error measures:
#                        ME      RMSE        MAE      MPE     MAPE      MASE
# Training set -0.005798481 0.0862278 0.06725892 105.0991 205.5009 0.3373521
#                    ACF1
# Training set -0.4752431

# %%
coeftest(mdlsat)
# Out:
# z test of coefficients:
#
#                  Estimate Std. Error z value  Pr(>|z|)
# ar1            -0.8688857  0.1267991 -6.8525 7.259e-12 ***
# SIE_lag4       -0.4043528  0.1204830 -3.3561 0.0007905 ***
# GyreSPD         0.0609860  0.0331533  1.8395 0.0658389 .
# GyreSPD_lag4    0.0761910  0.0224689  3.3909 0.0006965 ***
# nmSST_aw_RSP    0.5139370  0.1348971  3.8098 0.0001391 ***
# Fish_cum3       0.0055976  0.0026628  2.1021 0.0355413 *
# mnAirTemp_lag5 -0.0764922  0.0239276 -3.1968 0.0013895 **
# mnOW_RSP6       0.9041989  1.5935289  0.5674 0.5704294
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # We explored all the cuadratics and none of them improved the best model

# %%
#explore different percentages weights for cum_fish
#Fish= Total Tonnes * Perc.134/100
#Fish_cum3; 3 years cumulative, no weights
#Fish_cum_8_9_1; 3 years cumulative, weights: 80%, 90% ,100%
#Fish_cum_6_8_1; 3 years cumulative, weights: 60%, 80% ,100%
#Fish_cum_75_1; 2 years cumulative, weights: 75%, 100%
#Fish_cum; 2 years cumulative, no weights
#Fish_cum_5_1; 2 years cumulative, weights: 50%, 100%
#Fish_cum_4_1; 2 years cumulative, weights: 40%, 100%
#Fish_cum_2_1; 2 years cumulative, weights: 20%, 100%

# %%
## Explored various Fish_cum moving window configurations, best ones are Fich_cum3 and Fish_cum_8_9_1.
# That is: 0.75 prop134 at t-1 + prop134 at t
cov_sat_growth<-as.matrix(master_gr[,c("SIE_lag4", "GyreSPD", "GyreSPD_lag4",
                                "nmSST_aw_RSP", "Fish_cum_8_9_1",
                                       "mnAirTemp_lag5",  "mnOW_RSP6")]) 
mdlsat<-Arima(master_gr$growth_croz,order=c(1,0,0),include.mean=F,include.drift=F,xreg= cov_sat_growth)
summary(mdlsat)
# Out:
# Series: master_gr$growth_croz
# Regression with ARIMA(1,0,0) errors
#
# Coefficients:
#           ar1  SIE_lag4  GyreSPD  GyreSPD_lag4  nmSST_aw_RSP  Fish_cum_8_9_1
#       -0.8716   -0.4025   0.0601        0.0774        0.5154          0.0062
# s.e.   0.1254    0.1196   0.0324        0.0220        0.1334          0.0029
#       mnAirTemp_lag5  mnOW_RSP6
#              -0.0755     0.8992
# s.e.          0.0239     1.5748
#
# sigma^2 estimated as 0.01574:  log likelihood=14.86
# AIC=-11.71   AICc=24.29   BIC=-5.34
#
# Training set error measures:
#                        ME       RMSE        MAE      MPE     MAPE      MASE
# Training set -0.005890041 0.08569586 0.06674834 107.5772 207.3757 0.3347911
#                    ACF1
# Training set -0.4773048

# %%
coeftest(mdlsat)
# Out:
# z test of coefficients:
#
#                  Estimate Std. Error z value  Pr(>|z|)
# ar1            -0.8716408  0.1253834 -6.9518 3.606e-12 ***
# SIE_lag4       -0.4024788  0.1196304 -3.3644 0.0007672 ***
# GyreSPD         0.0600926  0.0323704  1.8564 0.0633958 .
# GyreSPD_lag4    0.0773695  0.0220442  3.5097 0.0004485 ***
# nmSST_aw_RSP    0.5153527  0.1334278  3.8624 0.0001123 ***
# Fish_cum_8_9_1  0.0062276  0.0028834  2.1598 0.0307909 *
# mnAirTemp_lag5 -0.0755252  0.0238528 -3.1663 0.0015439 **
# mnOW_RSP6       0.8991908  1.5748000  0.5710 0.5680082
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
checkresiduals (mdlsat, lag=15)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from Regression with ARIMA(1,0,0) errors
# Q* = NA, df = 7, p-value = NA
#
# Model df: 8.   Total lags used: 15
# plot without title

# %%
plot(residuals(mdlsat, type="response"))
# Out:
# plot without title

# %%
save(master_gr,mdlsat,cov_sat_growth,file="/home/ubuntu/Workspace/Anthropocene/data/bestModelfit.RData")

# %%
checkresiduals(mdlsatow)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from Regression with ARIMA(1,0,0) errors
# Q* = 16.778, df = 3, p-value = 0.0007851
#
# Model df: 7.   Total lags used: 10
# plot without title

# %% [markdown]
# # Checking for correlations

# %%
in_frame <- master_gr %>% select (mnSIE, SIE_lag4, GyreSPD, GyreSPD_lag4, mnWind, nmSST_aw_RSP, Cum_fish8, mnAirTemp_lag4, mnOW_RSP6)

# %%
#threshold at 10 (it’s equivalent to explaining 99% of the information in a variable by the set of the other covariates).

#select covariates based on variance inflation

vif_func<-function(in_frame,thresh=10,trace=T,...){
  
  
  
  if(class(in_frame) != 'data.frame') in_frame<-data.frame(in_frame)
  
  
  
  #get initial vif value for all comparisons of variables
  
  vif_init<-NULL
  
  var_names <- names(in_frame)
  
  for(val in var_names){
    
    regressors <- var_names[-which(var_names == val)]
    
    form <- paste(regressors, collapse = '+')
    
    form_in <- formula(paste(val, '~', form))
    
    vif_init<-rbind(vif_init, c(val, VIF(lm(form_in, data = in_frame, ...))))
    
  }
  
  vif_max<-max(as.numeric(vif_init[,2]), na.rm = TRUE)
  
  
  
  if(vif_max < thresh){
    
    if(trace==T){ #print output of each iteration
      
      prmatrix(vif_init,collab=c('var','vif'),rowlab=rep('',nrow(vif_init)),quote=F)
      
      cat('\n')
      
      cat(paste('All variables have VIF < ', thresh,', max VIF ',round(vif_max,2), sep=''),'\n\n')
      
    }
    
    return(var_names)
    
  }
  
  else{
    
    
    
    in_dat<-in_frame
    
    
    
    #backwards selection of explanatory variables, stops when all VIF values are below 'thresh'
    
    while(vif_max >= thresh){
      
      
      
      vif_vals<-NULL
      
      var_names <- names(in_dat)
      
      
      
      for(val in var_names){
        
        regressors <- var_names[-which(var_names == val)]
        
        form <- paste(regressors, collapse = '+')
        
        form_in <- formula(paste(val, '~', form))
        
        vif_add<-VIF(lm(form_in, data = in_dat, ...))
        
        vif_vals<-rbind(vif_vals,c(val,vif_add))
        
      }
      
      max_row<-which(vif_vals[,2] == max(as.numeric(vif_vals[,2]), na.rm = TRUE))[1]
      
      
      
      vif_max<-as.numeric(vif_vals[max_row,2])
      
      
      
      if(vif_max<thresh) break
      
      
      
      if(trace==T){ #print output of each iteration
        
        prmatrix(vif_vals,collab=c('var','vif'),rowlab=rep('',nrow(vif_vals)),quote=F)
        
        cat('\n')
        
        cat('removed: ',vif_vals[max_row,1],vif_max,'\n\n')
        
        flush.console()
        
      }
      
      
      
      in_dat<-in_dat[,!names(in_dat) %in% vif_vals[max_row,1]]
      
      
      
    }
    
    
    
    return(names(in_dat))
    
    
    
  }
  
  
  
}
  
vif_func(in_frame,thresh=10,trace=T)

# %% [markdown]
# # Partial dependence plots

# %%
## function to generate the data
# df is the source data.frame (master_gr)
# varv is the variable for which to construct the partial dependence plot
# meanmed indicates if fixing other variables to their mean or median value
# mdl is the model in which to evaluate the partial dependence
# type indicates if evaluating the dependence on a sequence of the predictor values or their real values
getPDdata<-function(df,varv, meanmed="mean", mdl, type="seq"){
    #get fixed values of constant vars
    cvars<-names(coef(mdl)); cvars<-cvars[which(!cvars %in% c(varv,"ar1","ar2","ar3"))]
    pddc<-sapply(cvars,function(vv,df,meanmed){
        mvv<-ifelse(meanmed=="mean",mean(df[,vv],na.rm=T),median(df[,vv],na.rm=T))
    },df=df,meanmed=meanmed)
    
    #get varying values of partial dependence var
    if(type=="seq"){
        minprv<-min(df[,varv],na.rm=T); maxprv<-max(df[,varv],na.rm=T)
        prv<-seq(minprv,maxprv,length.out=nrow(df))
    }else{
        prv<-unique(df[,varv])
    }
    pddf<-data.frame(prv=prv);names(pddf)<-varv
    
    #combine into matrix
    for(ii in 1:NROW(pddc)){
        cvn<-pddc[ii]; cvnn<-cvars[ii]
        pddf<-cbind(pddf,cvnv=rep(cvn,nrow(pddf)))
        names(pddf)<-gsub("cvnv",cvnn,names(pddf))
    }
    #must re-order as in the original matrix used to train the model
    cvars<-names(coef(mdl)); cvars<-cvars[which(!cvars %in% c("ar1","ar2","ar3"))]
    pddf<-pddf[,cvars]
    pdmx<-as.matrix(pddf)
    
    preds<-forecast(mdl,xreg=pdmx,level=95)
    plotdata<-data.frame(varv=prv,meanv=as.numeric(preds$mean),
                         lcv=as.numeric(preds$lower),ucv=as.numeric(preds$upper))
    names(plotdata)<-gsub("varv",varv,names(plotdata))
    return(plotdata)
}

# %%
pdat<-getPDdata(df=master_gr,varv="GyreSPD_lag4",mdl=mdlsat)
ggplot(pdat,aes(x=GyreSPD_lag4,y=meanv)) + geom_ribbon(aes(ymin=lcv,ymax=ucv),alpha=0.5) + geom_line(color="blue") +
    labs(x="Gyre speed (units?) lag 4 years", y = "Predicted log(growth rate)")
# Out:
# plot without title

# %%
pdat<-getPDdata(df=master_gr,varv="nmSST_aw_RSP",mdl=mod7)
ggplot(pdat,aes(x= nmSST_aw_RSP,y=meanv)) + geom_ribbon(aes(ymin=lcv,ymax=ucv),alpha=0.5) + geom_line(color="blue") +
    labs(x="Sea Surface Temperature (C)", y = "Predicted log(growth rate)")

# %%
#nmSST_aw_RSP
pdat<-getPDdata(df=master_gr,varv="SIE_lag4",mdl=mod7)
ggplot(pdat,aes(x= nmSST_aw_RSP,y=meanv)) + geom_ribbon(aes(ymin=lcv,ymax=ucv),alpha=0.5) + geom_line(color="blue") +
    labs(x="Sea Surface Temperature", y = "Predicted log(growth rate)", title="Arima model of order (1,0,0)")

# %%
pdat<-getPDdata(df=master_gr,varv="Fish_cum_75_1",mdl=mdlsat)
ggplot(pdat,aes(x=Prop._134,y=meanv)) + geom_ribbon(aes(ymin=lcv,ymax=ucv),alpha=0.5) + geom_line(color="blue") +
    labs(x="Proportion of Toothfish > 134 cm in catch", y = "Predicted log(growth rate)", title="Arima model of order (1,0,0)")
