# %% [markdown]
# # Finding the temporal autocorrelation order and evidence of slope
# This notebook fits an ARIMA model for WESE data looking for evidence of change

# %%
# Load libraries
library(forecast); library(ggplot2);library(plyr); library(dplyr); library(fmsb); library(stats); library(lmtest); library(modelr)

# %%
# Load the data
master<-read.csv("~/Workspace/Anthropocene/data/MASTER_SIE_MOD.csv")

# %%
master
# Out:
#    X  year intP_RSP  mnChl_aw_RSP mnOW_RSP nmSST_aw_RSP intP_MCM  mnChl_aw_MCM
# 1   1 1998 0.6511596 1.161487     250157   -0.690398    0.7170871 1.2969463
# 2   2 1999 0.6556949 1.353060     218399   -0.901666    0.7196705 1.5053741
# 3   3 2000 0.5873935 1.098477     200943   -0.924639    0.3527637 0.6385173
# 4   4 2001 0.7697252 1.460241     250135   -0.645706    1.0612940 3.1205994
# 5   5 2002 0.2079730 0.311760     100918   -1.117230    0.1219010 0.1905980
# 6   6 2003 0.6588100 1.278130     190735   -1.047010    0.1797500 0.2424260
# 7   7 2004 0.6595370 1.201000     268734   -0.546599    0.0595893 0.0920093
# 8   8 2005 0.6178970 1.116710     236044   -0.551816    0.2451990 0.5341190
# 9   9 2006 0.6735910 1.344420     218199   -0.970962    0.3927390 0.5908280
# 10 10 2007 0.5433250 1.170400     188097   -1.006890    0.3533950 0.6396110
# 11 11 2008 0.5252480 0.962226     241795   -0.846050    0.2566900 0.5890600
# 12 12 2009 0.7397130 1.811370     227884   -0.983647    0.4709990 1.1855100
# 13 13 2010 0.6582630 1.361110     254659   -0.702852    0.6655190 1.6221900
# 14 14 2011 0.5306270 0.988240     238928   -1.043260    0.3446910 0.5803630
# 15 15 2012 0.6193560 1.160120     224013   -0.806416    0.5633720 1.5237500
# 16 16 2013 0.4807330 0.760245     260754   -0.548099    0.5862910 1.1578700
# 17 17 2014 0.4698650 1.010510     184900   -0.946211    0.2947150 0.6039610
# 18 18 2015 0.5509990 1.069580     238508   -0.828653    0.6110260 1.3640600
# 19 19 2016 0.7154400 1.582850     235490   -0.661670    0.4544810 0.9937190
# 20 20 2017 0.3450750 0.608589     263830   -0.720451    0.2543610 0.4013860
# 21 21 2018 0.4303450 0.787736     245847   -0.820266    0.4504050 1.0538200
# 22 22 2019        NA       NA         NA          NA           NA        NA
#    mnOW_MCM nmSST_aw_MCM ⋯ ICEBERG ADPE_BIRD ADPE_CROZ ADPE_RO BIRD  EMPE
# 1  4370.76  -0.758259    ⋯  0      38252     125441    34110   38252 1108
# 2  4127.91  -0.926631    ⋯  0      47350     156441    36200   47350  798
# 3  2959.68  -1.109230    ⋯  0      41409      89489    23630   41409 1201
# 4  4366.66  -0.911519    ⋯  1      26317      67114    13670   26317    0
# 5  1748.01  -1.109550    ⋯  1      40678     161079    22390   40678  247
# 6  2701.45  -1.177640    ⋯  1      22816     100843    19630   22816  279
# 7  1115.63  -1.394120    ⋯  1      36773     182492    20360   36773  475
# 8  3630.16  -1.099050    ⋯  1      57709     194449    24590   57709    0
# 9  4718.94  -0.954533    ⋯  0      50326     205667    26070   50326  359
# 10 3903.53  -1.064650    ⋯  0      50595     197990    26540   50595  612
# 11 1968.25  -1.173800    ⋯  0      39285     193624    18050   39285  367
# 12 5003.04  -0.939651    ⋯  0      67122     282515    26090   67122  650
# 13 4676.62  -0.910408    ⋯  0      68525     278928    25130   68525  427
# 14 3446.75  -1.145310    ⋯  0      59875     261371    28870   59875  221
# 15 3799.97  -1.007750    ⋯  0      75696     272340    30830   75696 1080
# 16 4809.29  -0.529366    ⋯  0      66679     280787    29440   66679 1033
# 17 3855.74  -0.991542    ⋯  0      77347     281308    31870   77347 1238
# 18 4850.60  -0.801907    ⋯  0      74270     304733    31110   74270 1737
# 19 2029.15  -1.027590    ⋯  0      58554     280581    17460   58554 1759
# 20 3262.14  -1.148770    ⋯  0      63734     287091    26290   63734 1743
# 21 4958.09  -1.057240    ⋯  0      65205     312559    31030   65205 1911
# 22      NA         NA    ⋯ NA         NA         NA       NA      NA   NA
#    WESE      WESE_1 av_SIE FIE
# 1  0.6388527   NA   3.126  17.2
# 2  0.6505867   NA   3.269  31.0
# 3  0.6219035 1.05   2.983  37.2
# 4  0.5084746 0.75   2.964  15.0
# 5  0.5345502 0.80   2.779  44.9
# 6  0.5084746 0.78   2.859  52.0
# 7  0.2607562 0.35   2.759  14.9
# 8  0.3780965 0.55   2.832  47.0
# 9  0.5215124 0.95   2.738  47.0
# 10 0.6518905 1.25   3.126  23.0
# 11 0.5215124 0.75   3.167  20.0
# 12 0.6192960 1.10   3.071  38.0
# 13 0.7692308 1.43   2.980  18.0
# 14 0.7822686 1.38   2.756  18.0
# 15 0.7666232 1.35   2.789  16.0
# 16 0.7203604 1.30   3.113  18.0
# 17 0.7783572 1.40   3.029  20.0
# 18 0.8100851 1.45   2.890  20.0
# 19 0.6257191 1.10   2.709  15.0
# 20 0.9778357 1.65   2.417  60.0
# 21 0.5997393 1.00   2.647  13.5
# 22        NA 1.35      NA  15.4

# %%
#calculating the annual percentage change for WESE
master_gr <- master %>% mutate(growth_wese=log(WESE/lag(WESE)))%>% mutate(growth_wese_1=log(WESE_1/lag(WESE_1)))

# %%
master_gr<-subset(master_gr,year>2002 & year<2018)

# %%
head(master_gr)
# Out:
#   X  year intP_RSP mnChl_aw_RSP mnOW_RSP nmSST_aw_RSP intP_MCM  mnChl_aw_MCM
# 1  6 2003 0.658810 1.278130     190735   -1.047010    0.1797500 0.2424260
# 2  7 2004 0.659537 1.201000     268734   -0.546599    0.0595893 0.0920093
# 3  8 2005 0.617897 1.116710     236044   -0.551816    0.2451990 0.5341190
# 4  9 2006 0.673591 1.344420     218199   -0.970962    0.3927390 0.5908280
# 5 10 2007 0.543325 1.170400     188097   -1.006890    0.3533950 0.6396110
# 6 11 2008 0.525248 0.962226     241795   -0.846050    0.2566900 0.5890600
#   mnOW_MCM nmSST_aw_MCM ⋯ nmSST_aw_RSP_2 mnWind_2 GyreSPD_2 GyreSPD_lag4_2
# 1 2701.45  -1.177640    ⋯ 1.0962299      73.96    49.00     33.64
# 2 1115.63  -1.394120    ⋯ 0.2987705      70.56    51.84     32.49
# 3 3630.16  -1.099050    ⋯ 0.3045009      77.44    60.84     39.69
# 4 4718.94  -0.954533    ⋯ 0.9427672      77.44    29.16     38.44
# 5 3903.53  -1.064650    ⋯ 1.0138275      88.36    24.01     49.00
# 6 1968.25  -1.173800    ⋯ 0.7158006      67.24    54.76     51.84
#   GyreSPD_lag5_2 Salinity_2 intP_RSP_2 Prop._134_2 TOTALTonnes.100_2 mnSIE_2
# 1 25.00          1213.547   0.4340306  1225         201.0923          8.173881
# 2 33.64          1213.477   0.4349891  1444         426.2491          7.612081
# 3 32.49          1210.692   0.3817967  2025        1125.8508          8.020224
# 4 39.69          1211.040   0.4537248  1764         729.6968          7.496644
# 5 38.44                NA   0.2952021  1681         814.4232          9.771876
# 6 49.00          1212.432   0.2758855  1764         500.7257         10.029889

# %%
master_gr$mnOW_MCM6<- master_gr$mnOW_MCM/10^6

# %%
#lag 5 years SIE
master_gr <- master_gr %>% mutate(SIE_lag5 = lag(av_SIE,5))
master_gr[5,"SIE_lag5"]<-2.703
master_gr[4,"SIE_lag5"]<-3.123
master_gr[3,"SIE_lag5"]<-2.731
master_gr[2,"SIE_lag5"]<-2.767
master_gr[1,"SIE_lag5"]<-2.60

#lag 4 years SIE
master_gr <- master_gr %>% mutate(SIE_lag4 = lag(av_SIE,4))
master_gr[4,"SIE_lag4"]<-2.703
master_gr[3,"SIE_lag4"]<-3.123
master_gr[2,"SIE_lag4"]<-2.731
master_gr[1,"SIE_lag4"]<-2.767


#lag 4 years Gyre
master_gr <- master_gr %>% mutate(GyreSPD_lag4 = lag(GyreSPD,4))
master_gr[4,"GyreSPD_lag4"]<-6.2
master_gr[3,"GyreSPD_lag4"]<-6.3
master_gr[2,"GyreSPD_lag4"]<-5.7
master_gr[1,"GyreSPD_lag4"]<-5.8

#lag 5 years Gyre
master_gr <- master_gr %>% mutate(GyreSPD_lag5 = lag(GyreSPD,5))
master_gr[5,"GyreSPD_lag5"]<-6.2
master_gr[4,"GyreSPD_lag5"]<-6.3
master_gr[3,"GyreSPD_lag5"]<-5.7
master_gr[2,"GyreSPD_lag5"]<-5.8
master_gr[1,"GyreSPD_lag5"]<-5.0

#lag 5 years Air Temp
master_gr <- master_gr %>% mutate(mnAirTemp_lag5 = lag(mnAirTemp,5))
master_gr[5,"mnAirTemp_lag5"]<--5.6
master_gr[4,"mnAirTemp_lag5"]<--4.5
master_gr[3,"mnAirTemp_lag5"]<--5.2
master_gr[2,"mnAirTemp_lag5"]<--7.7
master_gr[1,"mnAirTemp_lag5"]<--4.2

#lag 4 years Air Temp
master_gr <- master_gr %>% mutate(mnAirTemp_lag4 = lag(mnAirTemp,4))
master_gr[5,"mnAirTemp_lag4"]<--5.6
master_gr[4,"mnAirTemp_lag4"]<--4.5
master_gr[3,"mnAirTemp_lag4"]<--5.2
master_gr[2,"mnAirTemp_lag4"]<--7.7


#lag 4 years FIE
master_gr <- master_gr %>% mutate(FIE_lag4 = lag(FIE,4))


# VARIABLES WITHOUT DATA FOR THE LAGGED YEARS (before 1998)

master_gr <- master_gr %>% mutate(mnWind_lag = lag(mnWind,5))
master_gr <- master_gr %>% mutate(Salinity_lag = lag(Salinity,5))
master_gr <- master_gr %>% mutate(mnSST_lag = lag(nmSST_aw_RSP,5))
master_gr <- master_gr %>% mutate(Prop134_lag = lag(Prop._134,5))
master_gr <- master_gr %>% mutate(FIE_lag4 = lag(FIE,4))

# %%
master_gr[which(year==2003),"FIE_lag4]<-52
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:29: unexpected INCOMPLETE_STRING
# 1: master_gr[which(year==2003),"FIE_lag4]<-52
#                                 ^
# Traceback:

# %%
master_gr[4,"FIE_lag4"]<-44.9
master_gr[3,"FIE_lag4"]<-15
master_gr[2,"FIE_lag4"]<-37.2
master_gr[1,"FIE_lag4"]<-31

# %%
# Quadratic variables
master_gr$FIE_2<- master_gr$FIE^2
master_gr$FIE_lag4_2<- master_gr$FIE_lag4^2
master_gr$SIE_lag4_2<- master_gr$SIE_lag4^2
master_gr$SIE_2<- master_gr$mnSIE^2
master_gr$mnAirTemp_2<- master_gr$mnAirTemp^2
master_gr$SIE_lag5_2<- master_gr$SIE_lag5^2
master_gr$mnOW_RSP6<- master_gr$mnOW_RSP/10^6
master_gr$mnOW_MCM6<- master_gr$mnOW_MCM/10^6
master_gr$mnOW_RSP6_2<-master_gr$mnOW_RSP6^2
master_gr$mnOW_MCM6_2<-master_gr$mnOW_MCM6^2
master_gr$mnChl_aw_RSP_2<-master_gr$mnChl_aw_RSP^2
master_gr$nmSST_aw_RSP_2<-master_gr$nmSST_aw_RSP^2
master_gr$mnWind_2<-master_gr$mnWind^2
master_gr$GyreSPD_2<-master_gr$GyreSPD^2
master_gr$GyreSPD_lag4_2<-master_gr$GyreSPD_lag4^2
master_gr$GyreSPD_lag5_2<-master_gr$GyreSPD_lag5^2
master_gr$Salinity_2<-master_gr$Salinity^2
master_gr$intP_RSP_2<-master_gr$intP_RSP^2
master_gr$Prop._134_2<-master_gr$Prop._134^2
master_gr$TOTALTonnes.100_2<-master_gr$TOTALTonnes.100^2
master_gr$mnSIE_2<- master_gr$mnSIE^2
master_gr$mnAirTemp_2<- master_gr$mnAirTemp^2

# %%
head(master_gr)
# Out:
#   X  year intP_RSP mnChl_aw_RSP mnOW_RSP nmSST_aw_RSP intP_MCM  mnChl_aw_MCM
# 1  6 2003 0.658810 1.278130     190735   -1.047010    0.1797500 0.2424260
# 2  7 2004 0.659537 1.201000     268734   -0.546599    0.0595893 0.0920093
# 3  8 2005 0.617897 1.116710     236044   -0.551816    0.2451990 0.5341190
# 4  9 2006 0.673591 1.344420     218199   -0.970962    0.3927390 0.5908280
# 5 10 2007 0.543325 1.170400     188097   -1.006890    0.3533950 0.6396110
# 6 11 2008 0.525248 0.962226     241795   -0.846050    0.2566900 0.5890600
#   mnOW_MCM nmSST_aw_MCM ⋯ nmSST_aw_RSP_2 mnWind_2 GyreSPD_2 GyreSPD_lag4_2
# 1 2701.45  -1.177640    ⋯ 1.0962299      73.96    49.00     33.64
# 2 1115.63  -1.394120    ⋯ 0.2987705      70.56    51.84     32.49
# 3 3630.16  -1.099050    ⋯ 0.3045009      77.44    60.84     39.69
# 4 4718.94  -0.954533    ⋯ 0.9427672      77.44    29.16     38.44
# 5 3903.53  -1.064650    ⋯ 1.0138275      88.36    24.01     49.00
# 6 1968.25  -1.173800    ⋯ 0.7158006      67.24    54.76     51.84
#   GyreSPD_lag5_2 Salinity_2 intP_RSP_2 Prop._134_2 TOTALTonnes.100_2 mnSIE_2
# 1 25.00          1213.547   0.4340306  1225         201.0923          8.173881
# 2 33.64          1213.477   0.4349891  1444         426.2491          7.612081
# 3 32.49          1210.692   0.3817967  2025        1125.8508          8.020224
# 4 39.69          1211.040   0.4537248  1764         729.6968          7.496644
# 5 38.44                NA   0.2952021  1681         814.4232          9.771876
# 6 49.00          1212.432   0.2758855  1764         500.7257         10.029889

# %%
ggplot(master_gr, aes(x=year, y= growth_wese))+geom_point()
# Out:
# plot without title

# %% [markdown]
# # Arima model with growth_wese

# %%
#checking best model
mdl1<-Arima(master_gr$growth_wese,order=c(1,0,0),include.mean=F,include.drift=T)
summary(mdl1)
# Out:
# Series: master_gr$growth_wese
# ARIMA(1,0,0) with drift
#
# Coefficients:
#           ar1   drift
#       -0.2007  0.0053
# s.e.   0.2624  0.0064
#
# sigma^2 estimated as 0.08113:  log likelihood=-1.39
# AIC=8.79   AICc=10.97   BIC=10.91
#
# Training set error measures:
#                        ME      RMSE      MAE      MPE    MAPE      MASE
# Training set -0.007265932 0.2651714 0.199058 99.61922 110.026 0.6713674
#                     ACF1
# Training set -0.07204383

# %%
checkresiduals(mdl1)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from ARIMA(1,0,0) with drift
# Q* = 3.4025, df = 3, p-value = 0.3336
#
# Model df: 2.   Total lags used: 5
# plot without title

# %% [markdown]
# ## Plotting the correct trend

# %%
wese<-master_gr$growth_wese
names(wese)<-master_gr$year

# %%
# Uncorrected trend
ggtsdisplay(wese)
# Out:
# plot without title

# %%
#threshold at 10 (it’s equivalent to explaining 99% of the information in a variable by the set of the other covariates).

#select covariates based on variance inflation

in_frame <- master_gr %>% select (intP_RSP:mnChl_aw_RSP, nmSST_aw_RSP:GyreSPD, Salinity, mnOW_RSP6:SIE_lag5, FIE, FIE_lag4)

vif_func<-function(in_frame,thresh=10,trace=T,...){
  
  
  
  if(class(in_frame) != 'data.frame') in_frame<-data.frame(in_frame)
  
  
  
  #get initial vif value for all comparisons of variables
  
  vif_init<-NULL
  
  var_names <- names(in_frame)
  
  for(val in var_names){
    
    regressors <- var_names[-which(var_names == val)]
    
    form <- paste(regressors, collapse = '+')
    
    form_in <- formula(paste(val, '~', form))
    
    vif_init<-rbind(vif_init, c(val, VIF(lm(form_in, data = in_frame, ...))))
    
  }
  
  vif_max<-max(as.numeric(vif_init[,2]), na.rm = TRUE)
  
  
  
  if(vif_max < thresh){
    
    if(trace==T){ #print output of each iteration
      
      prmatrix(vif_init,collab=c('var','vif'),rowlab=rep('',nrow(vif_init)),quote=F)
      
      cat('\n')
      
      cat(paste('All variables have VIF < ', thresh,', max VIF ',round(vif_max,2), sep=''),'\n\n')
      
    }
    
    return(var_names)
    
  }
  
  else{
    
    
    
    in_dat<-in_frame
    
    
    
    #backwards selection of explanatory variables, stops when all VIF values are below 'thresh'
    
    while(vif_max >= thresh){
      
      
      
      vif_vals<-NULL
      
      var_names <- names(in_dat)
      
      
      
      for(val in var_names){
        
        regressors <- var_names[-which(var_names == val)]
        
        form <- paste(regressors, collapse = '+')
        
        form_in <- formula(paste(val, '~', form))
        
        vif_add<-VIF(lm(form_in, data = in_dat, ...))
        
        vif_vals<-rbind(vif_vals,c(val,vif_add))
        
      }
      
      max_row<-which(vif_vals[,2] == max(as.numeric(vif_vals[,2]), na.rm = TRUE))[1]
      
      
      
      vif_max<-as.numeric(vif_vals[max_row,2])
      
      
      
      if(vif_max<thresh) break
      
      
      
      if(trace==T){ #print output of each iteration
        
        prmatrix(vif_vals,collab=c('var','vif'),rowlab=rep('',nrow(vif_vals)),quote=F)
        
        cat('\n')
        
        cat('removed: ',vif_vals[max_row,1],vif_max,'\n\n')
        
        flush.console()
        
      }
      
      
      
      in_dat<-in_dat[,!names(in_dat) %in% vif_vals[max_row,1]]
      
      
      
    }
    
    
    
    return(names(in_dat))
    
    
    
  }
  
  
  
}
  
vif_func(in_frame,thresh=10,trace=T)
# Out:
#  var            vif
#  intP_RSP       Inf
#  mnChl_aw_RSP   Inf
#  nmSST_aw_RSP   Inf
#  intP_MCM       Inf
#  mnChl_aw_MCM   Inf
#  mnOW_MCM       Inf
#  nmSST_aw_MCM   Inf
#  mnAirTemp      Inf
#  mnWind         Inf
#  mnSIE          Inf
#  GyreSPD        Inf
#  Salinity       Inf
#  mnOW_RSP6      Inf
#  SIE_lag5_2     Inf
#  mnAirTemp_2    Inf
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  intP_RSP Inf
#
#  var            vif
#  mnChl_aw_RSP   Inf
#  nmSST_aw_RSP   Inf
#  intP_MCM       Inf
#  mnChl_aw_MCM   Inf
#  mnOW_MCM       Inf
#  nmSST_aw_MCM   Inf
#  mnAirTemp      Inf
#  mnWind         Inf
#  mnSIE          Inf
#  GyreSPD        Inf
#  Salinity       Inf
#  mnOW_RSP6      Inf
#  SIE_lag5_2     Inf
#  mnAirTemp_2    Inf
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  mnChl_aw_RSP Inf
#
#  var            vif
#  nmSST_aw_RSP   Inf
#  intP_MCM       Inf
#  mnChl_aw_MCM   Inf
#  mnOW_MCM       Inf
#  nmSST_aw_MCM   Inf
#  mnAirTemp      Inf
#  mnWind         Inf
#  mnSIE          Inf
#  GyreSPD        Inf
#  Salinity       Inf
#  mnOW_RSP6      Inf
#  SIE_lag5_2     Inf
#  mnAirTemp_2    Inf
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  nmSST_aw_RSP Inf
#
#  var            vif
#  intP_MCM       Inf
#  mnChl_aw_MCM   Inf
#  mnOW_MCM       Inf
#  nmSST_aw_MCM   Inf
#  mnAirTemp      Inf
#  mnWind         Inf
#  mnSIE          Inf
#  GyreSPD        Inf
#  Salinity       Inf
#  mnOW_RSP6      Inf
#  SIE_lag5_2     Inf
#  mnAirTemp_2    Inf
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  intP_MCM Inf
#
#  var            vif
#  mnChl_aw_MCM   Inf
#  mnOW_MCM       Inf
#  nmSST_aw_MCM   Inf
#  mnAirTemp      Inf
#  mnWind         Inf
#  mnSIE          Inf
#  GyreSPD        Inf
#  Salinity       Inf
#  mnOW_RSP6      Inf
#  SIE_lag5_2     Inf
#  mnAirTemp_2    Inf
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  mnChl_aw_MCM Inf
#
#  var            vif
#  mnOW_MCM       Inf
#  nmSST_aw_MCM   Inf
#  mnAirTemp      Inf
#  mnWind         Inf
#  mnSIE          Inf
#  GyreSPD        Inf
#  Salinity       Inf
#  mnOW_RSP6      Inf
#  SIE_lag5_2     Inf
#  mnAirTemp_2    Inf
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  mnOW_MCM Inf
#
#  var            vif
#  nmSST_aw_MCM   Inf
#  mnAirTemp      Inf
#  mnWind         Inf
#  mnSIE          Inf
#  GyreSPD        Inf
#  Salinity       Inf
#  mnOW_RSP6      Inf
#  SIE_lag5_2     Inf
#  mnAirTemp_2    Inf
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  nmSST_aw_MCM Inf
#
#  var            vif
#  mnAirTemp      Inf
#  mnWind         Inf
#  mnSIE          Inf
#  GyreSPD        Inf
#  Salinity       Inf
#  mnOW_RSP6      Inf
#  SIE_lag5_2     Inf
#  mnAirTemp_2    Inf
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  mnAirTemp Inf
#
#  var            vif
#  mnWind         Inf
#  mnSIE          Inf
#  GyreSPD        Inf
#  Salinity       Inf
#  mnOW_RSP6      Inf
#  SIE_lag5_2     Inf
#  mnAirTemp_2    Inf
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  mnWind Inf
#
#  var            vif
#  mnSIE          Inf
#  GyreSPD        Inf
#  Salinity       Inf
#  mnOW_RSP6      Inf
#  SIE_lag5_2     Inf
#  mnAirTemp_2    Inf
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  mnSIE Inf
#
#  var            vif
#  GyreSPD        Inf
#  Salinity       Inf
#  mnOW_RSP6      Inf
#  SIE_lag5_2     Inf
#  mnAirTemp_2    Inf
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  GyreSPD Inf
#
#  var            vif
#  Salinity       Inf
#  mnOW_RSP6      Inf
#  SIE_lag5_2     Inf
#  mnAirTemp_2    Inf
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  Salinity Inf
#
#  var            vif
#  mnOW_RSP6      Inf
#  SIE_lag5_2     Inf
#  mnAirTemp_2    Inf
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  mnOW_RSP6 Inf
#
#  var            vif
#  SIE_lag5_2     Inf
#  mnAirTemp_2    Inf
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  SIE_lag5_2 Inf
#
#  var            vif
#  mnAirTemp_2    Inf
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  mnAirTemp_2 Inf
#
#  var            vif
#  SIE_2          Inf
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  SIE_2 Inf
#  var            vif
#  SIE_lag4_2     Inf
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  SIE_lag4_2 Inf
#
#  var            vif
#  FIE_lag4_2     Inf
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  FIE_lag4_2 Inf
#
#  var            vif
#  FIE_2          Inf
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  FIE_2 Inf
#
#  var            vif
#  FIE_lag4       Inf
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  FIE_lag4 Inf
#
#  var            vif
#  Prop134_lag    Inf
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  Prop134_lag Inf
#
#  var            vif
#  mnSST_lag      Inf
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  mnSST_lag Inf
#
#  var            vif
#  Salinity_lag   Inf
#  mnWind_lag     Inf
#  mnAirTemp_lag4 Inf
#  mnAirTemp_lag5 Inf
#  GyreSPD_lag5   Inf
#  GyreSPD_lag4   Inf
#  SIE_lag4       Inf
#  SIE_lag5       Inf
#  FIE            Inf
#
# removed:  Salinity_lag Inf
#
#  var            vif
#  mnWind_lag     14.6720380525387
#  mnAirTemp_lag4 14.3324416046077
#  mnAirTemp_lag5 14.7130243848289
#  GyreSPD_lag5   38.7118637874515
#  GyreSPD_lag4   2.83054387988901
#  SIE_lag4       74.7812656592956
#  SIE_lag5       35.124838913941
#  FIE            11.6598984069729
#
# removed:  SIE_lag4 74.78127
#
#  var            vif
#  mnWind_lag     6.48244114289401
#  mnAirTemp_lag4 5.11158977439692
#  mnAirTemp_lag5 11.4864403452325
#  GyreSPD_lag5   2.10998215475059
#  GyreSPD_lag4   1.85666507538118
#  SIE_lag5       2.57818735630795
#  FIE            1.87359576095589
#
# removed:  mnAirTemp_lag5 11.48644
# [1] "mnWind_lag"     "mnAirTemp_lag4" "GyreSPD_lag5"   "GyreSPD_lag4"
# [5] "SIE_lag5"       "FIE"

# %%
master_gr1 <-master_gr %>% filter(ICEBERG ==0)

# %% [markdown]
# # Including the saturated model

# %%
model_wese<- lm(growth_wese~ FIE+ FIE_lag4 + GyreSPD + GyreSPD_lag5 + mnWind + nmSST_aw_MCM + Cum_Fish + Cum_Fish_lag1 + mnAirTemp +  mnOW_MCM6, data=master_gr)

# %%
summary(model_wese)
# Out:
# Call:
# lm(formula = growth_wese ~ FIE + FIE_lag4 + GyreSPD + GyreSPD_lag5 +
#     mnWind + nmSST_aw_MCM + Cum_Fish + Cum_Fish_lag1 + mnAirTemp +
#     mnOW_MCM6, data = master_gr)
#
# Residuals:
#          1          2          3          4          5          6          7
#  0.0108438 -0.0958359 -0.0717096 -0.1139467  0.1209386 -0.0454957 -0.1162729
#          8          9         10         11         12         13         14
#  0.1256453  0.0294892 -0.0266890 -0.0005458  0.0698124 -0.0720373  0.0293927
#         15
#  0.1564109
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -1.426402   1.056121  -1.351    0.248
# FIE             0.007011   0.003875   1.809    0.145
# FIE_lag4       -0.006638   0.005942  -1.117    0.327
# GyreSPD         0.014442   0.110886   0.130    0.903
# GyreSPD_lag5   -0.010882   0.144318  -0.075    0.944
# mnWind          0.012809   0.233085   0.055    0.959
# nmSST_aw_MCM   -0.181660   1.075778  -0.169    0.874
# Cum_Fish        0.023076   0.028773   0.802    0.467
# Cum_Fish_lag1  -0.007526   0.023919  -0.315    0.769
# mnAirTemp      -0.018702   0.163824  -0.114    0.915
# mnOW_MCM6     202.756590 174.859475   1.160    0.311
#
# Residual standard error: 0.1661 on 4 degrees of freedom
# Multiple R-squared:  0.9014,	Adjusted R-squared:  0.655
# F-statistic: 3.658 on 10 and 4 DF,  p-value: 0.1115

# %%
nrow(master_gr)
# Out:
# [1] 15

# %%
master_gr[,c("year","FIE", "FIE_lag4", "GyreSPD", "GyreSPD_lag5" ,"mnWind", "nmSST_aw_MCM" ,"Cum_Fish", "Cum_Fish_lag1", "mnAirTemp", "mnOW_MCM6")]
# Out:
#    year FIE  FIE_lag4 GyreSPD GyreSPD_lag5 mnWind nmSST_aw_MCM Cum_Fish
# 1  2003 52.0 31.0     7.0     5.0           8.6   -1.177640    12.08450
# 2  2004 14.9 37.2     7.2     5.8           8.4   -1.394120    15.87784
# 3  2005 47.0 15.0     7.8     5.7           8.8   -1.099050    24.35344
# 4  2006 47.0 44.9     5.4     6.3           8.8   -0.954533    28.13199
# 5  2007 23.0 52.0     4.9     6.2           9.4   -1.064650    29.83645
# 6  2008 20.0 14.9     7.4     7.0           8.2   -1.173800    25.56605
# 7  2009 38.0 47.0     6.1     7.2           9.2   -0.939651    23.28909
# 8  2010 18.0 47.0     7.8     7.8           8.8   -0.910408    23.17439
# 9  2011 18.0 23.0     5.6     5.4           8.6   -1.145310    21.30917
# 10 2012 16.0 20.0     6.4     4.9           8.0   -1.007750    18.97371
# 11 2013 18.0 38.0     5.0     7.4           8.8   -0.529366    15.40439
# 12 2014 20.0 18.0     6.7     6.1           9.2   -0.991542    13.76449
# 13 2015 20.0 18.0     7.4     7.8          10.4   -0.801907    10.32313
# 14 2016 15.0 16.0     6.6     5.6           8.2   -1.027590    15.79582
# 15 2017 60.0 18.0     7.3     6.4           8.8   -1.148770    18.53000
#    Cum_Fish_lag1 mnAirTemp mnOW_MCM6
# 1  10.24868      -4.625    0.00270145
# 2  12.08450      -5.000    0.00111563
# 3  15.87784      -5.250    0.00363016
# 4  24.35344      -6.000    0.00471894
# 5  28.13199      -6.800    0.00390353
# 6  29.83645      -5.025    0.00196825
# 7  25.56605      -5.475    0.00500304
# 8  23.28909      -4.800    0.00467662
# 9  23.17439      -4.475    0.00344675
# 10 21.30917      -4.325    0.00379997
# 11 18.97371      -5.475    0.00480929
# 12 15.40439      -5.425    0.00385574
# 13 13.76449      -5.275    0.00485060
# 14 10.32313      -6.175    0.00202915
# 15 15.79582      -4.700    0.00326214

# %%
step(model_wese, k=2.77)
# Out:
# Start:  AIC=-43.2
# growth_wese ~ FIE + FIE_lag4 + GyreSPD + GyreSPD_lag5 + mnWind +
#     nmSST_aw_MCM + Cum_Fish + Cum_Fish_lag1 + mnAirTemp + mnOW_MCM6
#
#                 Df Sum of Sq     RSS     AIC
# - mnWind         1  0.000083 0.11049 -45.964
# - GyreSPD_lag5   1  0.000157 0.11056 -45.954
# - mnAirTemp      1  0.000360 0.11076 -45.926
# - GyreSPD        1  0.000468 0.11087 -45.911
# - nmSST_aw_MCM   1  0.000787 0.11119 -45.868
# - Cum_Fish_lag1  1  0.002733 0.11314 -45.608
# - Cum_Fish       1  0.017753 0.12816 -43.738
# <none>                       0.11040 -43.205
# - FIE_lag4       1  0.034446 0.14485 -41.902
# - mnOW_MCM6      1  0.037110 0.14752 -41.628
# - FIE            1  0.090343 0.20075 -37.006
#
# Step:  AIC=-45.96
# growth_wese ~ FIE + FIE_lag4 + GyreSPD + GyreSPD_lag5 + nmSST_aw_MCM +
#     Cum_Fish + Cum_Fish_lag1 + mnAirTemp + mnOW_MCM6
#
#                 Df Sum of Sq     RSS     AIC
# - GyreSPD_lag5   1  0.000075 0.11056 -48.723
# - GyreSPD        1  0.000399 0.11089 -48.680
# - mnAirTemp      1  0.001301 0.11179 -48.558
# - Cum_Fish_lag1  1  0.002752 0.11324 -48.365
# - nmSST_aw_MCM   1  0.004041 0.11453 -48.195
# <none>                       0.11049 -45.964
# - Cum_Fish       1  0.024163 0.13465 -45.767
# - FIE_lag4       1  0.048036 0.15852 -43.319
# - FIE            1  0.090794 0.20128 -39.737
# - mnOW_MCM6      1  0.179081 0.28957 -34.281
#
# Step:  AIC=-48.72
# growth_wese ~ FIE + FIE_lag4 + GyreSPD + nmSST_aw_MCM + Cum_Fish +
#     Cum_Fish_lag1 + mnAirTemp + mnOW_MCM6
#
#                 Df Sum of Sq     RSS     AIC
# - GyreSPD        1  0.000500 0.11106 -51.426
# - mnAirTemp      1  0.001409 0.11197 -51.303
# - Cum_Fish_lag1  1  0.006343 0.11691 -50.657
# - nmSST_aw_MCM   1  0.006772 0.11733 -50.602
# <none>                       0.11056 -48.723
# - Cum_Fish       1  0.036383 0.14694 -47.226
# - FIE_lag4       1  0.073528 0.18409 -43.846
# - FIE            1  0.094457 0.20502 -42.231
# - mnOW_MCM6      1  0.185816 0.29638 -36.703
#
# Step:  AIC=-51.43
# growth_wese ~ FIE + FIE_lag4 + nmSST_aw_MCM + Cum_Fish + Cum_Fish_lag1 +
#     mnAirTemp + mnOW_MCM6
#
#                 Df Sum of Sq     RSS     AIC
# - mnAirTemp      1  0.001006 0.11207 -54.060
# - nmSST_aw_MCM   1  0.007528 0.11859 -53.212
# - Cum_Fish_lag1  1  0.007975 0.11904 -53.156
# <none>                       0.11106 -51.426
# - Cum_Fish       1  0.039034 0.15010 -49.678
# - FIE_lag4       1  0.085109 0.19617 -45.662
# - FIE            1  0.093967 0.20503 -45.000
# - mnOW_MCM6      1  0.189710 0.30077 -39.252
#
# Step:  AIC=-54.06
# growth_wese ~ FIE + FIE_lag4 + nmSST_aw_MCM + Cum_Fish + Cum_Fish_lag1 +
#     mnOW_MCM6
#
#                 Df Sum of Sq     RSS     AIC
# - nmSST_aw_MCM   1  0.006564 0.11863 -55.977
# - Cum_Fish_lag1  1  0.013413 0.12548 -55.135
# <none>                       0.11207 -54.060
# - Cum_Fish       1  0.067646 0.17972 -49.747
# - FIE_lag4       1  0.087128 0.19920 -48.203
# - FIE            1  0.093443 0.20551 -47.735
# - mnOW_MCM6      1  0.193715 0.30578 -41.774
#
# Step:  AIC=-55.98
# growth_wese ~ FIE + FIE_lag4 + Cum_Fish + Cum_Fish_lag1 + mnOW_MCM6
#
#                 Df Sum of Sq     RSS     AIC
# - Cum_Fish_lag1  1   0.01280 0.13143 -57.209
# <none>                       0.11863 -55.977
# - Cum_Fish       1   0.07751 0.19615 -51.204
# - FIE_lag4       1   0.08424 0.20287 -50.698
# - FIE            1   0.13649 0.25512 -47.261
# - mnOW_MCM6      1   0.41417 0.53281 -36.215
#
# Step:  AIC=-57.21
# growth_wese ~ FIE + FIE_lag4 + Cum_Fish + mnOW_MCM6
#
#             Df Sum of Sq     RSS     AIC
# <none>                   0.13143 -57.209
# - FIE_lag4   1   0.07944 0.21087 -52.888
# - Cum_Fish   1   0.11921 0.25064 -50.297
# - FIE        1   0.24750 0.37894 -44.096
# - mnOW_MCM6  1   0.44531 0.57674 -37.796
# Call:
# lm(formula = growth_wese ~ FIE + FIE_lag4 + Cum_Fish + mnOW_MCM6,
#     data = master_gr)
#
# Coefficients:
# (Intercept)          FIE     FIE_lag4     Cum_Fish    mnOW_MCM6
#   -0.947862     0.008688    -0.006552     0.017544   163.574752

# %%
#trying model above
model_wese<- lm(formula = growth_wese ~ FIE + FIE_lag4 + Cum_Fish + mnOW_MCM6, data = master_gr)
summary (model_wese)
# Out:
# Call:
# lm(formula = growth_wese ~ FIE + FIE_lag4 + Cum_Fish + mnOW_MCM6,
#     data = master_gr)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.12944 -0.07272 -0.01168  0.07620  0.14993
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.947862   0.135572  -6.992 3.75e-05 ***
# FIE           0.008688   0.002002   4.339 0.001468 **
# FIE_lag4     -0.006552   0.002665  -2.458 0.033768 *
# Cum_Fish      0.017544   0.005825   3.012 0.013082 *
# mnOW_MCM6   163.574752  28.102254   5.821 0.000168 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1146 on 10 degrees of freedom
# Multiple R-squared:  0.8826,	Adjusted R-squared:  0.8357
# F-statistic:  18.8 on 4 and 10 DF,  p-value: 0.0001205

# %%
#trying Cum_fish
model_wese<- lm(formula = growth_wese ~ FIE + FIE_lag4 + Cum_fish2 + mnOW_MCM6, data = master_gr)
summary (model_wese)
# Out:
# Call:
# lm(formula = growth_wese ~ FIE + FIE_lag4 + Cum_fish2 + mnOW_MCM6,
#     data = master_gr)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.12235 -0.07422 -0.02654  0.07181  0.15353
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.951136   0.133099  -7.146 3.12e-05 ***
# FIE           0.008280   0.001992   4.157 0.001957 **
# FIE_lag4     -0.006422   0.002595  -2.475 0.032843 *
# Cum_fish2     0.020117   0.006448   3.120 0.010875 *
# mnOW_MCM6   165.894439  27.653499   5.999 0.000132 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1127 on 10 degrees of freedom
# Multiple R-squared:  0.8866,	Adjusted R-squared:  0.8412
# F-statistic: 19.54 on 4 and 10 DF,  p-value: 0.0001019
